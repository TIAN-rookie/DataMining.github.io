# %% [markdown]
# # Environment

# %%
# !pip install torch-geometric
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install ogb
# Out:
# Collecting torch-geometric
#   Downloading torch_geometric-2.0.4.tar.gz (407 kB)
#      |████████████████████████████████| 407 kB 5.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.63.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.1.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.4-py3-none-any.whl size=616603 sha256=3c33fd0dc30763cc13a50d825cd74f53ec8113b99acf7936c0628e312d692f1f
#   Stored in directory: /root/.cache/pip/wheels/18/a6/a4/ca18c3051fcead866fe7b85700ee2240d883562a1bc70ce421
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.0.4
#      |████████████████████████████████| 7.9 MB 5.3 MB/s
#      |████████████████████████████████| 3.5 MB 5.3 MB/s
# Collecting ogb
#   Downloading ogb-1.3.3-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.7 MB/s
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (4.63.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.0.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.15.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.3.5)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.24.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.21.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.10.0+cu111)
# Collecting outdated>=0.2.0
#   Downloading outdated-0.2.1-py3-none-any.whl (7.5 kB)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from outdated>=0.2.0->ogb) (2.23.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->ogb) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->ogb) (2.8.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->ogb) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->ogb) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->ogb) (3.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->ogb) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->outdated>=0.2.0->ogb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->outdated>=0.2.0->ogb) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->outdated>=0.2.0->ogb) (2.10)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=92c6dc190f3506f473f6b3a9c2b5d1a7cf301d7f9acfc4b87d38a430a10a49e7
#   Stored in directory: /root/.cache/pip/wheels/d6/64/cd/32819b511a488e4993f2fab909a95330289c3f4e0f6ef4676d
# Successfully built littleutils
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.2 ogb-1.3.3 outdated-0.2.1

# %%
from typing import Callable, Optional
from torch_geometric.typing import Adj, OptTensor
import torch
from torch import Tensor
import torch.nn.functional as F
from torch_sparse import SparseTensor, matmul
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.conv.gcn_conv import gcn_norm
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import ModuleList, Linear, BatchNorm1d
import torch.optim as optim
import numpy as np
from torch_geometric.nn import GCNConv, GATConv, SAGEConv, JumpingKnowledge
from torch_geometric.data import NeighborSampler
import torch_geometric.transforms as T
from ogb.nodeproppred import PygNodePropPredDataset, Evaluator

# %% [markdown]
# # Label Propagation

# %%
class LabelPropagation(MessagePassing):


    def __init__(self, num_layers: int, alpha: float):
        super(LabelPropagation, self).__init__(aggr='add')
        self.num_layers = num_layers
        self.alpha = alpha

    @torch.no_grad()
    def forward(
            self, y: Tensor, edge_index: Adj, mask: Optional[Tensor] = None,
            edge_weight: OptTensor = None,
            post_step: Callable = lambda y: y.clamp_(0., 1.)
    ) -> Tensor:
        """"""

        if y.dtype == torch.long:
            y = F.one_hot(y.view(-1)).to(torch.float)

        out = y
        if mask is not None:
            out = torch.zeros_like(y)
            out[mask] = y[mask]

        if isinstance(edge_index, SparseTensor) and not edge_index.has_value():
            edge_index = gcn_norm(edge_index, add_self_loops=False)
        elif isinstance(edge_index, Tensor) and edge_weight is None:
            edge_index, edge_weight = gcn_norm(edge_index, num_nodes=y.size(0),
                                               add_self_loops=False)

        res = (1 - self.alpha) * out
        for _ in range(self.num_layers):
            # propagate_type: (y: Tensor, edge_weight: OptTensor)
            out = self.propagate(edge_index, x=out, edge_weight=edge_weight,
                                 size=None)
            out.mul_(self.alpha).add_(res)
            out = post_step(out)

        return out

    def message(self, x_j: Tensor, edge_weight: OptTensor) -> Tensor:
        return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j

    def message_and_aggregate(self, adj_t: SparseTensor, x: Tensor) -> Tensor:
        return matmul(adj_t, x, reduce=self.aggr)

    def __repr__(self):
        return '{}(num_layers={}, alpha={})'.format(self.__class__.__name__,
                                                    self.num_layers,
                                                    self.alpha)

# %% [markdown]
# # C&S

# %%
class CorrectAndSmooth(torch.nn.Module):


    def __init__(self, num_correction_layers: int, correction_alpha: float,
                 num_smoothing_layers: int, smoothing_alpha: float,
                 autoscale: bool = True, scale: float = 1.0):
        super(CorrectAndSmooth, self).__init__()
        self.autoscale = autoscale
        self.scale = scale

        self.prop1 = LabelPropagation(num_correction_layers, correction_alpha)
        self.prop2 = LabelPropagation(num_smoothing_layers, smoothing_alpha)

    def correct(self, y_soft: Tensor, y_true: Tensor, mask: Tensor,
                edge_index: Adj, edge_weight: OptTensor = None) -> Tensor:
        r"""
        Args:
            y_soft (Tensor): The soft predictions :math:`\mathbf{Z}` obtained
                from a simple base predictor.
            y_true (Tensor): The ground-truth label information
                :math:`\mathbf{Y}` of training nodes.
            mask (LongTensor or BoolTensor): A mask or index tensor denoting
                which nodes were used for training.
            edge_index (Tensor or SparseTensor): The edge connectivity.
            edge_weight (Tensor, optional): The edge weights.
                (default: :obj:`None`)
        """
        assert abs((float(y_soft.sum()) / y_soft.size(0)) - 1.0) < 1e-2

        numel = int(mask.sum()) if mask.dtype == torch.bool else mask.size(0)
        assert y_true.size(0) == numel

        if y_true.dtype == torch.long:
            y_true = F.one_hot(y_true.view(-1), y_soft.size(-1))
            y_true = y_true.to(y_soft.dtype)

        error = torch.zeros_like(y_soft)
        error[mask] = y_true - y_soft[mask]

        if self.autoscale:
            smoothed_error = self.prop1(error, edge_index,
                                        edge_weight=edge_weight,
                                        post_step=lambda x: x.clamp_(-1., 1.))

            sigma = error[mask].abs().sum() / numel
            scale = sigma / smoothed_error.abs().sum(dim=1, keepdim=True)
            scale[scale.isinf() | (scale > 1000)] = 1.0
            return y_soft + scale * smoothed_error
        else:

            def fix_input(x):
                x[mask] = error[mask]
                return x

            smoothed_error = self.prop1(error, edge_index,
                                        edge_weight=edge_weight,
                                        post_step=fix_input)
            return y_soft + self.scale * smoothed_error

    def smooth(self, y_soft: Tensor, y_true: Tensor, mask: Tensor,
               edge_index: Adj, edge_weight: OptTensor = None) -> Tensor:

        numel = int(mask.sum()) if mask.dtype == torch.bool else mask.size(0)
        assert y_true.size(0) == numel

        if y_true.dtype == torch.long:
            y_true = F.one_hot(y_true.view(-1), y_soft.size(-1))
            y_true = y_true.to(y_soft.dtype)

        y_soft[mask] = y_true

        return self.prop2(y_soft, edge_index, edge_weight=edge_weight)

    def __repr__(self):
        L1, alpha1 = self.prop1.num_layers, self.prop1.alpha
        L2, alpha2 = self.prop2.num_layers, self.prop2.alpha
        return (f'{self.__class__.__name__}(\n'
                f'    correct: num_layers={L1}, alpha={alpha1}\n'
                f'    smooth:  num_layers={L2}, alpha={alpha2}\n'
                f'    autoscale={self.autoscale}, scale={self.scale}\n'
                ')')

# %% [markdown]
# # Model

# %% [markdown]
# ## Dataset

# %%
# Load dataset
dataset = PygNodePropPredDataset(name='ogbn-arxiv', root='./arxiv/', transform=T.ToSparseTensor())
# dataset = PygNodePropPredDataset(name='ogbn-products', root='./products/', transform=T.ToSparseTensor())
print(dataset)
data = dataset[0]
print(data)

# Split dataset
split_idx = dataset.get_idx_split()

# Define evaluator
evaluator = Evaluator(name='ogbn-arxiv')
# evaluator = Evaluator(name='ogbn-products')

train_idx = split_idx['train']
test_idx = split_idx['test']
# Out:
# Downloading http://snap.stanford.edu/ogb/data/nodeproppred/arxiv.zip
# Downloaded 0.08 GB: 100%|██████████| 81/81 [00:02<00:00, 27.44it/s]
# Extracting ./arxiv/arxiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████| 1/1 [00:00<00:00, 649.27it/s]
# Converting graphs into PyG objects...
# 100%|██████████| 1/1 [00:00<00:00, 1683.78it/s]
# Saving...
# Done!
# PygNodePropPredDataset()
# Data(num_nodes=169343, x=[169343, 128], node_year=[169343, 1], y=[169343, 1], adj_t=[169343, 169343, nnz=1166243])

# %% [markdown]
# ## GCN, GCN res, GAT res

# %%
# Define Net
# GCN
class GCNNet(nn.Module):
    def __init__(self, dataset, hidden=256, num_layers=3):
        """
        :param dataset: 数据集
        :param hidden: 隐藏层维度，默认256
        :param num_layers: 模型层数，默认为3
        """
        super(GCNNet, self).__init__()

        self.num_layers = num_layers
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()

        self.convs.append(GCNConv(dataset.num_node_features, hidden))
        self.bns.append(nn.BatchNorm1d(hidden))

        for i in range(self.num_layers - 2):
            self.convs.append(GCNConv(hidden, hidden))
            self.bns.append(nn.BatchNorm1d(hidden))

        self.convs.append(GCNConv(hidden, dataset.num_classes))

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()

    def forward(self, data):
        x, adj_t = data.x, data.adj_t

        for i in range(self.num_layers - 1):
            x = self.convs[i](x, adj_t)
            x = self.bns[i](x)  # 小数据集不norm反而效果更好
            x = F.relu(x)
            x = F.dropout(x, p=0.5, training=self.training)

        x = self.convs[-1](x, adj_t)
        x = F.log_softmax(x, dim=1)

        return x


# GCN_res
class GCN_res(nn.Module):
    def __init__(self, dataset, hidden=256, num_layers=6):
        super(GCN_res, self).__init__()

        self.num_layers = num_layers
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()

        self.input_fc = nn.Linear(dataset.num_node_features, hidden)

        for i in range(self.num_layers):
            self.convs.append(GCNConv(hidden, hidden))
            self.bns.append(nn.BatchNorm1d(hidden))

        self.out_fc = nn.Linear(hidden, dataset.num_classes)
        self.weights = torch.nn.Parameter(torch.randn((len(self.convs))))

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()
        self.input_fc.reset_parameters()
        self.out_fc.reset_parameters()
        torch.nn.init.normal_(self.weights)

    def forward(self, data):
        x, adj_t = data.x, data.adj_t

        x = self.input_fc(x)
        x_input = x  # .copy()

        layer_out = []  # 保存每一层的结果
        for i in range(self.num_layers):
            x = self.convs[i](x, adj_t)
            x = self.bns[i](x)
            x = F.relu(x, inplace=True)
            x = F.dropout(x, p=0.5, training=self.training)

            if i == 0:
                x = x + 0.2 * x_input
            else:
                x = x + 0.2 * x_input + 0.7 * layer_out[i - 1]
            layer_out.append(x)

        weight = F.softmax(self.weights, dim=0)
        for i in range(len(layer_out)):
            layer_out[i] = layer_out[i] * weight[i]

        x = sum(layer_out)
        x = self.out_fc(x)
        x = F.log_softmax(x, dim=1)

        return x

# GAT_res
class GAT_res(nn.Module):
    def __init__(self, dataset, hidden=256, num_layers=3, hidden_channels=64, num_head=4):
        super(GAT_res, self).__init__()

        self.num_layers = num_layers
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()

        self.input_fc = nn.Linear(dataset.num_node_features, hidden)

#         for i in range(self.num_layers):
#             self.convs.append(GCNConv(hidden, hidden))
#             self.bns.append(nn.BatchNorm1d(hidden))


        self.conv1 = GATConv(hidden,
                     hidden_channels,
                     num_head,
#                      0.2,
#                      0.2
                            )
        self.conv2 = GATConv(hidden_channels*num_head,
                     hidden_channels,
                     num_head,
#                      0.2,
#                      0.2
                            )
        self.conv3 = GATConv(hidden_channels*num_head,
                     hidden,
                     1,
#                      0.2,
#                      0.2
                            )
        self.convs.append(self.conv1)
        self.convs.append(self.conv2)
        self.convs.append(self.conv3)
        self.bns.append(nn.BatchNorm1d(hidden_channels*num_head))
        self.bns.append(nn.BatchNorm1d(hidden_channels*num_head))
        self.bns.append(nn.BatchNorm1d(hidden))
        
        self.out_fc = nn.Linear(hidden, dataset.num_classes)
        self.weights = torch.nn.Parameter(torch.randn((len(self.convs))))

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()
        self.input_fc.reset_parameters()
        self.out_fc.reset_parameters()
        torch.nn.init.normal_(self.weights)

    def forward(self, data):
        x, adj_t = data.x, data.adj_t

        x = self.input_fc(x)
        x_input = x  # .copy()

        layer_out = []  # 保存每一层的结果
        for i in range(self.num_layers):
            x = self.convs[i](x, adj_t)
            x = self.bns[i](x)
            x = F.relu(x, inplace=True)
            x = F.dropout(x, p=0.5, training=self.training)

            if i == 0:
                x = x + 0.2 * x_input
            else:
                x = x + 0.2 * x_input + 0.7 * layer_out[i - 1]
            layer_out.append(x)

        weight = F.softmax(self.weights, dim=0)
        for i in range(len(layer_out)):
            layer_out[i] = layer_out[i] * weight[i]

        x = sum(layer_out)
        x = self.out_fc(x)
        x = F.log_softmax(x, dim=1)

        return x

# %% [markdown]
# ## LOSS, Train, Test Function

# %%
# model = GCNNet(dataset=dataset, hidden=256, num_layers=3)
model = GCN_res(dataset=dataset, hidden=128, num_layers=8)
#model = GAT_res(dataset=dataset, hidden=256, num_layers=3, hidden_channels=64, num_head=4)
print(model)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model.to(device)
data = data.to(device)
data.adj_t = data.adj_t.to_symmetric()  
# train_idx = train_idx.to(device)

x, y = data.x.to(device), data.y.to(device)
train_idx = split_idx['train'].to(device)
val_idx = split_idx['valid'].to(device)
test_idx = split_idx['test'].to(device)
x_train, y_train = x[train_idx], y[train_idx]
x_val, y_val = x[val_idx], y[val_idx]

train_val_idx = torch.cat((train_idx,val_idx),dim=0)
y_train_val = y[train_val_idx].to(device)

x_train = x_train.to(device)
y_train = y_train.to(device)
train_val_idx = train_val_idx.to(device)

adj_t = data.adj_t.to(device)
deg = adj_t.sum(dim=1).to(torch.float)
deg_inv_sqrt = deg.pow_(-0.5)
deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
DAD = deg_inv_sqrt.view(-1, 1) * adj_t * deg_inv_sqrt.view(1, -1)
DA = deg_inv_sqrt.view(-1, 1) * deg_inv_sqrt.view(-1, 1) * adj_t
AD = adj_t * deg_inv_sqrt.view(-1, 1) * deg_inv_sqrt.view(-1, 1)

# Define Loss function and optimizer
criterion = nn.NLLLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)


# Define Train function
def train():
    model.train()

    out = model(data)
    loss = criterion(out[train_idx], data.y.squeeze(1)[train_idx])

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return loss.item()


# Define Test function
@torch.no_grad()
def test(out=None):
    model.eval()

    out = model(data) if out is None else out
    y_pred = out.argmax(dim=-1, keepdim=True)

    train_acc = evaluator.eval({
        'y_true': data.y[split_idx['train']],
        'y_pred': y_pred[split_idx['train']],
    })['acc']
    valid_acc = evaluator.eval({
        'y_true': data.y[split_idx['valid']],
        'y_pred': y_pred[split_idx['valid']],
    })['acc']
    test_acc = evaluator.eval({
        'y_true': data.y[split_idx['test']],
        'y_pred': y_pred[split_idx['test']],
    })['acc']

    return train_acc, valid_acc, test_acc, out
# Out:
# GCN_res(
#   (convs): ModuleList(
#     (0): GCNConv(128, 128)
#     (1): GCNConv(128, 128)
#     (2): GCNConv(128, 128)
#     (3): GCNConv(128, 128)
#     (4): GCNConv(128, 128)
#     (5): GCNConv(128, 128)
#     (6): GCNConv(128, 128)
#     (7): GCNConv(128, 128)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (input_fc): Linear(in_features=128, out_features=128, bias=True)
#   (out_fc): Linear(in_features=128, out_features=40, bias=True)
# )
# cuda

# %%
class Logger(object):
    def __init__(self, runs, info=None):
        self.info = info
        self.results = [[] for _ in range(runs)]

    def add_result(self, run, result):
        assert len(result) == 3
        assert run >= 0 and run < len(self.results)
        self.results[run].append(result)

    def print_statistics(self, run=None, print_all=True):
        if run is not None:
            result = 100 * torch.tensor(self.results[run])
            argmax = result[:, 1].argmax().item()
            print(f'Run {run + 1:02d}:')
            print(f'Highest Train: {result[:, 0].max():.2f}')
            print(f'Highest Valid: {result[:, 1].max():.2f}')
            print(f'  Final Train: {result[argmax, 0]:.2f}')
            print(f'   Final Test: {result[argmax, 2]:.2f}')
        else:
            result = 100 * torch.tensor(self.results)

            best_results = []
            for r in result:
                train1 = r[:, 0].max().item()
                valid = r[:, 1].max().item()
                train2 = r[r[:, 1].argmax(), 0].item()
                test = r[r[:, 1].argmax(), 2].item()
                best_results.append((train1, valid, train2, test))

            best_result = torch.tensor(best_results)

            print(f'All runs:')
            if print_all:
                r = best_result[:, 0]
                print(f'Highest Train: {r.mean():.2f} ± {r.std():.2f}')
                r = best_result[:, 1]
                print(f'Highest Valid: {r.mean():.2f} ± {r.std():.2f}')
                r = best_result[:, 2]
                print(f'  Final Train: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 3]
            print(f'   Final Test: {r.mean():.2f} ± {r.std():.2f}')

# %% [markdown]
# # Main Fiction

# %%
# main
if __name__ == '__main__':
   
    runs = 10
    logger = Logger(runs)

    for run in range(runs):
        print(sum(p.numel() for p in model.parameters()))
        model.reset_parameters()

        best_val_acc = 0

        for epoch in range(500):
            loss = train()
            # print('Epoch {:03d} train_loss: {:.4f}'.format(epoch, loss))

            train_acc, val_acc, test_acc, out = test()
            result = (train_acc, val_acc, test_acc)
            # print(f'Train: {train_acc:.4f}, Val: {valid_acc:.4f}, 'f'Test: {test_acc:.4f}')
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                y_soft = out.softmax(dim=-1)

            print(f'Run: {run + 1:02d}, '
                  f'Epoch: {epoch:02d}, '
                  f'Loss: {loss:.4f}, '
                  f'Train: {100 * train_acc:.2f}%, '
                  f'Valid: {100 * val_acc:.2f}% '
                  f'Test: {100 * test_acc:.2f}%')

            # logger.add_result(run, result)

        # post = CorrectAndSmooth(num_correction_layers=50, correction_alpha=1.0,
        #                         num_smoothing_layers=50, smoothing_alpha=0.8,
        #                         autoscale=False, scale=20.)

        z_val = y_soft[val_idx]

        post = CorrectAndSmooth(num_correction_layers=50, correction_alpha=0.7,
                                num_smoothing_layers=50, smoothing_alpha=0.7,
                                autoscale=False, scale=1.)

        print('Correct and smooth...')
        # y_soft = post.correct(y_soft, y_train, train_idx, DAD)
        # y_soft = post.smooth(y_soft, y_train, train_idx, DA)

        # y_soft = post.correct(y_soft, y_train, train_idx, DAD)
        # y_soft = post.smooth(y_soft, y_train, train_idx, DAD)

        y_soft = post.correct(y_soft, y_train_val, train_val_idx, DAD)
        y_soft = post.smooth(y_soft, y_train_val, train_val_idx, DAD)

        print('Done!')
        y_soft[val_idx] = z_val
        train_acc, val_acc, test_acc, _ = test(y_soft)
        print(f'Train: {train_acc:.4f}, Val: {val_acc:.4f}, Test: {test_acc:.4f}')

        result = (train_acc, val_acc, test_acc)
        logger.add_result(run, result)

    logger.print_statistics()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Run: 01, Epoch: 44, Loss: 1.1296, Train: 67.28%, Valid: 67.14% Test: 65.32%
# Run: 01, Epoch: 45, Loss: 1.1267, Train: 67.69%, Valid: 67.61% Test: 65.78%
# Run: 01, Epoch: 46, Loss: 1.1205, Train: 68.11%, Valid: 67.77% Test: 65.84%
# Run: 01, Epoch: 47, Loss: 1.1152, Train: 68.24%, Valid: 68.27% Test: 66.87%
# Run: 01, Epoch: 48, Loss: 1.1086, Train: 68.05%, Valid: 68.09% Test: 67.00%
# Run: 01, Epoch: 49, Loss: 1.1070, Train: 67.98%, Valid: 67.94% Test: 66.91%
# Run: 01, Epoch: 50, Loss: 1.0997, Train: 68.77%, Valid: 68.78% Test: 67.82%
# Run: 01, Epoch: 51, Loss: 1.0977, Train: 68.84%, Valid: 68.58% Test: 67.44%
# Run: 01, Epoch: 52, Loss: 1.0878, Train: 68.53%, Valid: 67.87% Test: 66.23%
# Run: 01, Epoch: 53, Loss: 1.0859, Train: 68.52%, Valid: 68.14% Test: 66.67%
# Run: 01, Epoch: 54, Loss: 1.0830, Train: 68.85%, Valid: 68.46% Test: 67.06%
# Run: 01, Epoch: 55, Loss: 1.0774, Train: 69.38%, Valid: 69.39% Test: 67.97%
# Run: 01, Epoch: 56, Loss: 1.0721, Train: 69.59%, Valid: 69.74% Test: 68.43%
# Run: 01, Epoch: 57, Loss: 1.0675, Train: 69.64%, Valid: 70.05% Test: 69.50%
# Run: 01, Epoch: 58, Loss: 1.0633, Train: 69.18%, Valid: 69.43% Test: 69.38%
# Run: 01, Epoch: 59, Loss: 1.0587, Train: 69.23%, Valid: 69.56% Test: 69.28%
# Run: 01, Epoch: 60, Loss: 1.0541, Train: 69.61%, Valid: 69.24% Test: 67.93%
# Run: 01, Epoch: 61, Loss: 1.0539, Train: 69.85%, Valid: 68.95% Test: 66.99%
# Run: 01, Epoch: 62, Loss: 1.0499, Train: 69.95%, Valid: 69.09% Test: 67.53%
# Run: 01, Epoch: 63, Loss: 1.0459, Train: 70.01%, Valid: 69.72% Test: 69.24%
# Run: 01, Epoch: 64, Loss: 1.0421, Train: 70.11%, Valid: 69.82% Test: 69.58%
# Run: 01, Epoch: 65, Loss: 1.0411, Train: 70.28%, Valid: 70.06% Test: 69.71%
# Run: 01, Epoch: 66, Loss: 1.0356, Train: 70.12%, Valid: 69.44% Test: 68.76%
# Run: 01, Epoch: 67, Loss: 1.0340, Train: 69.95%, Valid: 69.62% Test: 68.64%
# Run: 01, Epoch: 68, Loss: 1.0318, Train: 70.21%, Valid: 70.06% Test: 69.53%
# Run: 01, Epoch: 69, Loss: 1.0276, Train: 70.55%, Valid: 70.54% Test: 70.66%
# Run: 01, Epoch: 70, Loss: 1.0228, Train: 70.08%, Valid: 70.06% Test: 69.89%
# Run: 01, Epoch: 71, Loss: 1.0222, Train: 69.38%, Valid: 68.71% Test: 67.75%
# Run: 01, Epoch: 72, Loss: 1.0171, Train: 70.46%, Valid: 70.17% Test: 68.82%
# Run: 01, Epoch: 73, Loss: 1.0178, Train: 70.93%, Valid: 70.63% Test: 69.76%
# Run: 01, Epoch: 74, Loss: 1.0132, Train: 70.33%, Valid: 69.73% Test: 69.99%
# Run: 01, Epoch: 75, Loss: 1.0083, Train: 70.30%, Valid: 70.01% Test: 70.16%
# Run: 01, Epoch: 76, Loss: 1.0064, Train: 71.33%, Valid: 70.88% Test: 70.25%
# Run: 01, Epoch: 77, Loss: 1.0064, Train: 70.70%, Valid: 70.05% Test: 68.75%
# Run: 01, Epoch: 78, Loss: 1.0020, Train: 70.31%, Valid: 69.35% Test: 67.70%
# Run: 01, Epoch: 79, Loss: 1.0001, Train: 71.02%, Valid: 70.26% Test: 69.06%
# Run: 01, Epoch: 80, Loss: 0.9960, Train: 71.46%, Valid: 70.79% Test: 69.30%
# Run: 01, Epoch: 81, Loss: 0.9959, Train: 71.19%, Valid: 70.46% Test: 69.82%
# Run: 01, Epoch: 82, Loss: 0.9923, Train: 70.70%, Valid: 69.36% Test: 68.63%
# Run: 01, Epoch: 83, Loss: 0.9897, Train: 71.14%, Valid: 70.00% Test: 69.01%
# Run: 01, Epoch: 84, Loss: 0.9865, Train: 71.02%, Valid: 70.32% Test: 69.79%
# Run: 01, Epoch: 85, Loss: 0.9863, Train: 70.89%, Valid: 68.99% Test: 67.07%
# Run: 01, Epoch: 86, Loss: 0.9843, Train: 70.55%, Valid: 70.49% Test: 69.37%
# Run: 01, Epoch: 87, Loss: 0.9834, Train: 71.01%, Valid: 70.52% Test: 69.77%
# Run: 01, Epoch: 88, Loss: 0.9783, Train: 70.56%, Valid: 68.80% Test: 67.66%
# Run: 01, Epoch: 89, Loss: 0.9794, Train: 68.35%, Valid: 66.27% Test: 66.08%
# Run: 01, Epoch: 90, Loss: 0.9792, Train: 69.27%, Valid: 67.16% Test: 66.44%
# Run: 01, Epoch: 91, Loss: 0.9743, Train: 71.54%, Valid: 70.19% Test: 68.81%
# Run: 01, Epoch: 92, Loss: 0.9747, Train: 70.43%, Valid: 68.95% Test: 68.32%
# Run: 01, Epoch: 93, Loss: 0.9719, Train: 70.40%, Valid: 69.74% Test: 69.55%
# Run: 01, Epoch: 94, Loss: 0.9700, Train: 71.64%, Valid: 70.64% Test: 69.42%
# Run: 01, Epoch: 95, Loss: 0.9660, Train: 72.16%, Valid: 70.90% Test: 69.30%
# Run: 01, Epoch: 96, Loss: 0.9635, Train: 71.25%, Valid: 70.20% Test: 68.60%
# Run: 01, Epoch: 97, Loss: 0.9600, Train: 71.26%, Valid: 68.93% Test: 66.65%
# Run: 01, Epoch: 98, Loss: 0.9640, Train: 71.37%, Valid: 70.78% Test: 70.61%
# Run: 01, Epoch: 99, Loss: 0.9568, Train: 71.80%, Valid: 70.96% Test: 70.81%
# Run: 01, Epoch: 100, Loss: 0.9574, Train: 72.33%, Valid: 70.98% Test: 69.69%
# Run: 01, Epoch: 101, Loss: 0.9553, Train: 72.33%, Valid: 71.23% Test: 70.40%
# Run: 01, Epoch: 102, Loss: 0.9515, Train: 71.65%, Valid: 70.65% Test: 69.93%
# Run: 01, Epoch: 103, Loss: 0.9519, Train: 72.13%, Valid: 70.81% Test: 69.62%
# Run: 01, Epoch: 104, Loss: 0.9484, Train: 71.78%, Valid: 70.55% Test: 69.06%
# Run: 01, Epoch: 105, Loss: 0.9483, Train: 70.82%, Valid: 70.63% Test: 69.69%
# Run: 01, Epoch: 106, Loss: 0.9476, Train: 70.73%, Valid: 68.63% Test: 68.55%
# Run: 01, Epoch: 107, Loss: 0.9469, Train: 71.71%, Valid: 69.18% Test: 66.86%
# Run: 01, Epoch: 108, Loss: 0.9426, Train: 71.92%, Valid: 69.59% Test: 67.89%
# Run: 01, Epoch: 109, Loss: 0.9419, Train: 71.90%, Valid: 70.57% Test: 70.21%
# Run: 01, Epoch: 110, Loss: 0.9406, Train: 71.18%, Valid: 68.83% Test: 67.35%
# Run: 01, Epoch: 111, Loss: 0.9386, Train: 71.40%, Valid: 69.94% Test: 68.54%
# Run: 01, Epoch: 112, Loss: 0.9356, Train: 71.75%, Valid: 69.20% Test: 67.72%
# Run: 01, Epoch: 113, Loss: 0.9372, Train: 71.19%, Valid: 69.48% Test: 67.57%
# Run: 01, Epoch: 114, Loss: 0.9362, Train: 72.13%, Valid: 71.06% Test: 70.04%
# Run: 01, Epoch: 115, Loss: 0.9318, Train: 70.60%, Valid: 69.23% Test: 68.91%
# Run: 01, Epoch: 116, Loss: 0.9331, Train: 71.72%, Valid: 70.90% Test: 69.74%
# Run: 01, Epoch: 117, Loss: 0.9294, Train: 71.20%, Valid: 69.63% Test: 68.51%
# Run: 01, Epoch: 118, Loss: 0.9250, Train: 71.71%, Valid: 69.61% Test: 68.69%
# Run: 01, Epoch: 119, Loss: 0.9261, Train: 70.07%, Valid: 67.56% Test: 65.37%
# Run: 01, Epoch: 120, Loss: 0.9304, Train: 70.85%, Valid: 68.98% Test: 67.67%
# Run: 01, Epoch: 121, Loss: 0.9242, Train: 72.01%, Valid: 69.71% Test: 68.46%
# Run: 01, Epoch: 122, Loss: 0.9261, Train: 72.29%, Valid: 70.59% Test: 68.80%
# Run: 01, Epoch: 123, Loss: 0.9235, Train: 72.46%, Valid: 71.36% Test: 70.38%
# Run: 01, Epoch: 124, Loss: 0.9228, Train: 71.34%, Valid: 70.06% Test: 69.30%
# Run: 01, Epoch: 125, Loss: 0.9173, Train: 71.42%, Valid: 70.44% Test: 69.32%
# Run: 01, Epoch: 126, Loss: 0.9172, Train: 71.85%, Valid: 69.52% Test: 66.92%
# Run: 01, Epoch: 127, Loss: 0.9142, Train: 71.32%, Valid: 68.58% Test: 66.10%
# Run: 01, Epoch: 128, Loss: 0.9127, Train: 71.82%, Valid: 70.57% Test: 69.86%
# Run: 01, Epoch: 129, Loss: 0.9102, Train: 72.78%, Valid: 71.60% Test: 71.53%
# Run: 01, Epoch: 130, Loss: 0.9086, Train: 73.05%, Valid: 71.35% Test: 71.46%
# Run: 01, Epoch: 131, Loss: 0.9097, Train: 72.79%, Valid: 70.68% Test: 69.68%
# Run: 01, Epoch: 132, Loss: 0.9102, Train: 72.28%, Valid: 70.22% Test: 68.65%
# Run: 01, Epoch: 133, Loss: 0.9056, Train: 72.25%, Valid: 70.32% Test: 69.21%
# Run: 01, Epoch: 134, Loss: 0.9060, Train: 72.90%, Valid: 70.85% Test: 69.68%
# Run: 01, Epoch: 135, Loss: 0.9005, Train: 72.90%, Valid: 71.11% Test: 69.79%
# Run: 01, Epoch: 136, Loss: 0.9049, Train: 72.64%, Valid: 70.57% Test: 69.23%
# Run: 01, Epoch: 137, Loss: 0.8995, Train: 72.71%, Valid: 70.56% Test: 69.97%
# Run: 01, Epoch: 138, Loss: 0.8998, Train: 73.07%, Valid: 71.36% Test: 70.30%
# Run: 01, Epoch: 139, Loss: 0.9003, Train: 73.47%, Valid: 70.94% Test: 68.89%
# Run: 01, Epoch: 140, Loss: 0.8990, Train: 72.99%, Valid: 70.62% Test: 68.58%
# Run: 01, Epoch: 141, Loss: 0.8952, Train: 72.89%, Valid: 71.49% Test: 70.43%
# Run: 01, Epoch: 142, Loss: 0.8929, Train: 73.19%, Valid: 71.87% Test: 71.42%
# Run: 01, Epoch: 143, Loss: 0.8951, Train: 72.13%, Valid: 69.96% Test: 69.57%
# Run: 01, Epoch: 144, Loss: 0.8954, Train: 71.28%, Valid: 68.69% Test: 66.68%
# Run: 01, Epoch: 145, Loss: 0.8935, Train: 72.75%, Valid: 69.54% Test: 67.05%
# Run: 01, Epoch: 146, Loss: 0.8921, Train: 73.11%, Valid: 70.89% Test: 69.25%
# Run: 01, Epoch: 147, Loss: 0.8906, Train: 73.71%, Valid: 71.59% Test: 70.13%
# Run: 01, Epoch: 148, Loss: 0.8918, Train: 73.62%, Valid: 72.21% Test: 71.54%
# Run: 01, Epoch: 149, Loss: 0.8838, Train: 73.31%, Valid: 71.33% Test: 71.38%
# Run: 01, Epoch: 150, Loss: 0.8842, Train: 72.87%, Valid: 70.79% Test: 69.07%
# Run: 01, Epoch: 151, Loss: 0.8844, Train: 73.14%, Valid: 71.54% Test: 70.18%
# Run: 01, Epoch: 152, Loss: 0.8842, Train: 72.84%, Valid: 70.85% Test: 69.84%
# Run: 01, Epoch: 153, Loss: 0.8851, Train: 73.38%, Valid: 71.60% Test: 70.85%
# Run: 01, Epoch: 154, Loss: 0.8801, Train: 72.57%, Valid: 71.00% Test: 69.67%
# Run: 01, Epoch: 155, Loss: 0.8787, Train: 72.46%, Valid: 70.75% Test: 68.89%
# Run: 01, Epoch: 156, Loss: 0.8776, Train: 74.18%, Valid: 71.69% Test: 70.16%
# Run: 01, Epoch: 157, Loss: 0.8773, Train: 73.91%, Valid: 71.59% Test: 70.66%
# Run: 01, Epoch: 158, Loss: 0.8754, Train: 73.70%, Valid: 71.55% Test: 70.59%
# Run: 01, Epoch: 159, Loss: 0.8759, Train: 74.26%, Valid: 72.36% Test: 71.13%
# Run: 01, Epoch: 160, Loss: 0.8750, Train: 72.79%, Valid: 70.34% Test: 70.14%
# Run: 01, Epoch: 161, Loss: 0.8731, Train: 72.77%, Valid: 70.82% Test: 70.42%
# Run: 01, Epoch: 162, Loss: 0.8714, Train: 73.56%, Valid: 71.75% Test: 71.13%
# Run: 01, Epoch: 163, Loss: 0.8701, Train: 73.58%, Valid: 71.62% Test: 70.75%
# Run: 01, Epoch: 164, Loss: 0.8717, Train: 74.12%, Valid: 72.14% Test: 70.63%
# Run: 01, Epoch: 165, Loss: 0.8689, Train: 74.02%, Valid: 71.46% Test: 70.32%
# Run: 01, Epoch: 166, Loss: 0.8682, Train: 73.63%, Valid: 71.21% Test: 70.46%
# Run: 01, Epoch: 167, Loss: 0.8662, Train: 74.36%, Valid: 71.78% Test: 70.33%
# Run: 01, Epoch: 168, Loss: 0.8652, Train: 74.32%, Valid: 72.02% Test: 71.28%
# Run: 01, Epoch: 169, Loss: 0.8639, Train: 74.44%, Valid: 72.51% Test: 71.65%
# Run: 01, Epoch: 170, Loss: 0.8624, Train: 74.11%, Valid: 71.80% Test: 70.36%
# Run: 01, Epoch: 171, Loss: 0.8600, Train: 74.43%, Valid: 72.02% Test: 70.82%
# Run: 01, Epoch: 172, Loss: 0.8600, Train: 74.08%, Valid: 71.78% Test: 70.53%
# Run: 01, Epoch: 173, Loss: 0.8603, Train: 74.55%, Valid: 72.43% Test: 71.49%
# Run: 01, Epoch: 174, Loss: 0.8591, Train: 73.63%, Valid: 71.19% Test: 70.13%
# Run: 01, Epoch: 175, Loss: 0.8615, Train: 73.94%, Valid: 72.07% Test: 70.76%
# Run: 01, Epoch: 176, Loss: 0.8605, Train: 74.04%, Valid: 71.91% Test: 70.91%
# Run: 01, Epoch: 177, Loss: 0.8593, Train: 73.43%, Valid: 70.00% Test: 67.72%
# Run: 01, Epoch: 178, Loss: 0.8584, Train: 73.85%, Valid: 71.80% Test: 70.58%
# Run: 01, Epoch: 179, Loss: 0.8572, Train: 74.19%, Valid: 72.20% Test: 71.00%
# Run: 01, Epoch: 180, Loss: 0.8594, Train: 73.82%, Valid: 70.76% Test: 68.35%
# Run: 01, Epoch: 181, Loss: 0.8577, Train: 73.79%, Valid: 71.19% Test: 69.05%
# Run: 01, Epoch: 182, Loss: 0.8547, Train: 73.76%, Valid: 71.05% Test: 69.93%
# Run: 01, Epoch: 183, Loss: 0.8537, Train: 74.06%, Valid: 70.60% Test: 68.07%
# Run: 01, Epoch: 184, Loss: 0.8519, Train: 74.33%, Valid: 71.10% Test: 69.28%
# Run: 01, Epoch: 185, Loss: 0.8538, Train: 74.12%, Valid: 71.85% Test: 70.83%
# Run: 01, Epoch: 186, Loss: 0.8508, Train: 73.98%, Valid: 72.05% Test: 72.01%
# Run: 01, Epoch: 187, Loss: 0.8493, Train: 74.19%, Valid: 71.80% Test: 70.28%
# Run: 01, Epoch: 188, Loss: 0.8499, Train: 74.33%, Valid: 71.68% Test: 70.00%
# Run: 01, Epoch: 189, Loss: 0.8491, Train: 74.48%, Valid: 71.74% Test: 70.64%
# Run: 01, Epoch: 190, Loss: 0.8472, Train: 74.14%, Valid: 71.26% Test: 69.00%
# Run: 01, Epoch: 191, Loss: 0.8475, Train: 74.43%, Valid: 70.95% Test: 68.54%
# Run: 01, Epoch: 192, Loss: 0.8429, Train: 74.59%, Valid: 72.38% Test: 71.26%
# Run: 01, Epoch: 193, Loss: 0.8424, Train: 73.44%, Valid: 70.41% Test: 70.60%
# Run: 01, Epoch: 194, Loss: 0.8448, Train: 74.31%, Valid: 71.75% Test: 70.14%
# Run: 01, Epoch: 195, Loss: 0.8415, Train: 74.05%, Valid: 71.09% Test: 69.14%
# Run: 01, Epoch: 196, Loss: 0.8416, Train: 73.65%, Valid: 69.78% Test: 67.13%
# Run: 01, Epoch: 197, Loss: 0.8403, Train: 74.83%, Valid: 71.62% Test: 70.59%
# Run: 01, Epoch: 198, Loss: 0.8364, Train: 74.52%, Valid: 72.08% Test: 71.29%
# Run: 01, Epoch: 199, Loss: 0.8393, Train: 74.89%, Valid: 72.38% Test: 71.02%
# Run: 01, Epoch: 200, Loss: 0.8365, Train: 74.88%, Valid: 72.85% Test: 72.33%
# Run: 01, Epoch: 201, Loss: 0.8369, Train: 74.82%, Valid: 72.07% Test: 71.09%
# Run: 01, Epoch: 202, Loss: 0.8359, Train: 73.95%, Valid: 71.51% Test: 70.35%
# Run: 01, Epoch: 203, Loss: 0.8374, Train: 74.34%, Valid: 71.69% Test: 69.73%
# Run: 01, Epoch: 204, Loss: 0.8343, Train: 74.99%, Valid: 72.55% Test: 70.94%
# Run: 01, Epoch: 205, Loss: 0.8356, Train: 73.43%, Valid: 71.28% Test: 70.60%
# Run: 01, Epoch: 206, Loss: 0.8367, Train: 74.82%, Valid: 72.04% Test: 70.66%
# Run: 01, Epoch: 207, Loss: 0.8381, Train: 75.13%, Valid: 72.16% Test: 70.79%
# Run: 01, Epoch: 208, Loss: 0.8315, Train: 74.33%, Valid: 71.25% Test: 69.76%
# Run: 01, Epoch: 209, Loss: 0.8351, Train: 74.98%, Valid: 71.15% Test: 68.85%
# Run: 01, Epoch: 210, Loss: 0.8332, Train: 74.42%, Valid: 71.14% Test: 69.27%
# Run: 01, Epoch: 211, Loss: 0.8335, Train: 74.06%, Valid: 71.50% Test: 71.22%
# Run: 01, Epoch: 212, Loss: 0.8311, Train: 74.50%, Valid: 71.61% Test: 71.30%
# Run: 01, Epoch: 213, Loss: 0.8312, Train: 74.52%, Valid: 71.25% Test: 69.57%
# Run: 01, Epoch: 214, Loss: 0.8300, Train: 74.29%, Valid: 70.79% Test: 69.42%
# Run: 01, Epoch: 215, Loss: 0.8293, Train: 74.87%, Valid: 71.38% Test: 69.98%
# Run: 01, Epoch: 216, Loss: 0.8270, Train: 75.21%, Valid: 72.10% Test: 70.65%
# Run: 01, Epoch: 217, Loss: 0.8293, Train: 74.94%, Valid: 72.37% Test: 71.67%
# Run: 01, Epoch: 218, Loss: 0.8264, Train: 75.05%, Valid: 72.26% Test: 70.98%
# Run: 01, Epoch: 219, Loss: 0.8258, Train: 75.07%, Valid: 72.59% Test: 71.53%
# Run: 01, Epoch: 220, Loss: 0.8255, Train: 74.56%, Valid: 71.91% Test: 71.20%
# Run: 01, Epoch: 221, Loss: 0.8217, Train: 75.14%, Valid: 71.88% Test: 70.42%
# Run: 01, Epoch: 222, Loss: 0.8224, Train: 74.86%, Valid: 71.00% Test: 68.65%
# Run: 01, Epoch: 223, Loss: 0.8204, Train: 75.43%, Valid: 72.37% Test: 71.01%
# Run: 01, Epoch: 224, Loss: 0.8195, Train: 75.08%, Valid: 72.00% Test: 70.63%
# Run: 01, Epoch: 225, Loss: 0.8198, Train: 75.04%, Valid: 71.89% Test: 69.58%
# Run: 01, Epoch: 226, Loss: 0.8203, Train: 75.17%, Valid: 71.49% Test: 69.41%
# Run: 01, Epoch: 227, Loss: 0.8192, Train: 75.33%, Valid: 72.12% Test: 70.38%
# Run: 01, Epoch: 228, Loss: 0.8154, Train: 74.68%, Valid: 69.88% Test: 66.87%
# Run: 01, Epoch: 229, Loss: 0.8165, Train: 75.60%, Valid: 72.10% Test: 70.32%
# Run: 01, Epoch: 230, Loss: 0.8162, Train: 74.65%, Valid: 71.22% Test: 71.00%
# Run: 01, Epoch: 231, Loss: 0.8148, Train: 74.83%, Valid: 72.02% Test: 71.62%
# Run: 01, Epoch: 232, Loss: 0.8122, Train: 75.64%, Valid: 73.09% Test: 72.40%
# Run: 01, Epoch: 233, Loss: 0.8139, Train: 75.04%, Valid: 72.01% Test: 71.22%
# Run: 01, Epoch: 234, Loss: 0.8170, Train: 75.31%, Valid: 72.06% Test: 70.45%
# Run: 01, Epoch: 235, Loss: 0.8129, Train: 75.63%, Valid: 72.56% Test: 70.80%
# Run: 01, Epoch: 236, Loss: 0.8096, Train: 75.60%, Valid: 72.08% Test: 70.71%
# Run: 01, Epoch: 237, Loss: 0.8122, Train: 75.40%, Valid: 72.08% Test: 70.84%
# Run: 01, Epoch: 238, Loss: 0.8060, Train: 75.08%, Valid: 71.74% Test: 71.34%
# Run: 01, Epoch: 239, Loss: 0.8141, Train: 75.35%, Valid: 72.22% Test: 71.07%
# Run: 01, Epoch: 240, Loss: 0.8090, Train: 75.08%, Valid: 70.10% Test: 67.61%
# Run: 01, Epoch: 241, Loss: 0.8116, Train: 74.33%, Valid: 71.08% Test: 70.44%
# Run: 01, Epoch: 242, Loss: 0.8087, Train: 75.23%, Valid: 72.10% Test: 71.52%
# Run: 01, Epoch: 243, Loss: 0.8060, Train: 75.69%, Valid: 72.49% Test: 71.28%
# Run: 01, Epoch: 244, Loss: 0.8071, Train: 75.86%, Valid: 72.25% Test: 71.45%
# Run: 01, Epoch: 245, Loss: 0.8065, Train: 75.88%, Valid: 71.76% Test: 70.65%
# Run: 01, Epoch: 246, Loss: 0.8058, Train: 75.68%, Valid: 72.12% Test: 70.93%
# Run: 01, Epoch: 247, Loss: 0.8025, Train: 74.23%, Valid: 70.00% Test: 69.44%
# Run: 01, Epoch: 248, Loss: 0.8060, Train: 75.74%, Valid: 72.29% Test: 70.45%
# Run: 01, Epoch: 249, Loss: 0.8029, Train: 74.06%, Valid: 68.14% Test: 66.18%
# Run: 01, Epoch: 250, Loss: 0.8033, Train: 75.09%, Valid: 72.38% Test: 71.81%
# Run: 01, Epoch: 251, Loss: 0.8046, Train: 75.78%, Valid: 72.99% Test: 72.63%
# Run: 01, Epoch: 252, Loss: 0.7984, Train: 75.84%, Valid: 72.40% Test: 71.58%
# Run: 01, Epoch: 253, Loss: 0.8013, Train: 75.64%, Valid: 71.36% Test: 69.35%
# Run: 01, Epoch: 254, Loss: 0.7971, Train: 75.29%, Valid: 70.88% Test: 69.24%
# Run: 01, Epoch: 255, Loss: 0.8009, Train: 75.67%, Valid: 72.01% Test: 70.73%
# Run: 01, Epoch: 256, Loss: 0.7989, Train: 76.24%, Valid: 72.54% Test: 71.19%
# Run: 01, Epoch: 257, Loss: 0.7979, Train: 76.10%, Valid: 72.66% Test: 71.11%
# Run: 01, Epoch: 258, Loss: 0.7978, Train: 76.25%, Valid: 72.84% Test: 71.86%
# Run: 01, Epoch: 259, Loss: 0.7974, Train: 76.18%, Valid: 72.90% Test: 71.75%
# Run: 01, Epoch: 260, Loss: 0.7938, Train: 75.60%, Valid: 72.62% Test: 71.32%
# Run: 01, Epoch: 261, Loss: 0.7966, Train: 75.00%, Valid: 70.09% Test: 68.12%
# Run: 01, Epoch: 262, Loss: 0.7978, Train: 75.17%, Valid: 70.79% Test: 69.61%
# Run: 01, Epoch: 263, Loss: 0.7983, Train: 74.15%, Valid: 67.88% Test: 65.52%
# Run: 01, Epoch: 264, Loss: 0.7993, Train: 75.43%, Valid: 71.81% Test: 70.23%
# Run: 01, Epoch: 265, Loss: 0.7959, Train: 75.83%, Valid: 72.27% Test: 71.10%
# Run: 01, Epoch: 266, Loss: 0.7926, Train: 74.57%, Valid: 71.08% Test: 69.70%
# Run: 01, Epoch: 267, Loss: 0.7959, Train: 76.00%, Valid: 73.25% Test: 72.61%
# Run: 01, Epoch: 268, Loss: 0.7914, Train: 75.37%, Valid: 72.15% Test: 71.79%
# Run: 01, Epoch: 269, Loss: 0.7988, Train: 75.69%, Valid: 72.01% Test: 69.99%
# Run: 01, Epoch: 270, Loss: 0.7927, Train: 76.30%, Valid: 72.37% Test: 70.38%
# Run: 01, Epoch: 271, Loss: 0.7958, Train: 76.25%, Valid: 73.29% Test: 72.13%
# Run: 01, Epoch: 272, Loss: 0.7910, Train: 76.05%, Valid: 73.11% Test: 71.84%
# Run: 01, Epoch: 273, Loss: 0.7913, Train: 76.23%, Valid: 72.84% Test: 71.25%
# Run: 01, Epoch: 274, Loss: 0.7889, Train: 75.74%, Valid: 71.57% Test: 69.44%
# Run: 01, Epoch: 275, Loss: 0.7887, Train: 76.36%, Valid: 71.64% Test: 69.36%
# Run: 01, Epoch: 276, Loss: 0.7875, Train: 76.17%, Valid: 72.07% Test: 70.01%
# Run: 01, Epoch: 277, Loss: 0.7873, Train: 75.60%, Valid: 70.80% Test: 68.74%
# Run: 01, Epoch: 278, Loss: 0.7859, Train: 76.32%, Valid: 72.90% Test: 71.56%
# Run: 01, Epoch: 279, Loss: 0.7866, Train: 76.30%, Valid: 72.90% Test: 72.05%
# Run: 01, Epoch: 280, Loss: 0.7850, Train: 75.86%, Valid: 71.99% Test: 70.95%
# Run: 01, Epoch: 281, Loss: 0.7846, Train: 75.54%, Valid: 70.35% Test: 68.71%
# Run: 01, Epoch: 282, Loss: 0.7798, Train: 75.61%, Valid: 71.38% Test: 70.04%
# Run: 01, Epoch: 283, Loss: 0.7819, Train: 76.40%, Valid: 72.54% Test: 71.24%
# Run: 01, Epoch: 284, Loss: 0.7842, Train: 76.65%, Valid: 73.29% Test: 72.39%
# Run: 01, Epoch: 285, Loss: 0.7808, Train: 76.60%, Valid: 73.09% Test: 71.47%
# Run: 01, Epoch: 286, Loss: 0.7835, Train: 76.40%, Valid: 72.75% Test: 71.24%
# Run: 01, Epoch: 287, Loss: 0.7815, Train: 76.59%, Valid: 72.97% Test: 71.89%
# Run: 01, Epoch: 288, Loss: 0.7796, Train: 76.54%, Valid: 72.37% Test: 70.20%
# Run: 01, Epoch: 289, Loss: 0.7789, Train: 76.14%, Valid: 70.98% Test: 68.68%
# Run: 01, Epoch: 290, Loss: 0.7824, Train: 76.51%, Valid: 72.03% Test: 70.49%
# Run: 01, Epoch: 291, Loss: 0.7766, Train: 76.29%, Valid: 72.47% Test: 70.47%
# Run: 01, Epoch: 292, Loss: 0.7797, Train: 76.67%, Valid: 72.72% Test: 71.45%
# Run: 01, Epoch: 293, Loss: 0.7785, Train: 76.21%, Valid: 72.04% Test: 71.36%
# Run: 01, Epoch: 294, Loss: 0.7772, Train: 76.46%, Valid: 72.91% Test: 71.53%
# Run: 01, Epoch: 295, Loss: 0.7755, Train: 76.45%, Valid: 72.77% Test: 71.60%
# Run: 01, Epoch: 296, Loss: 0.7773, Train: 76.06%, Valid: 71.87% Test: 70.97%
# Run: 01, Epoch: 297, Loss: 0.7777, Train: 76.51%, Valid: 71.93% Test: 70.53%
# Run: 01, Epoch: 298, Loss: 0.7727, Train: 76.69%, Valid: 72.19% Test: 70.32%
# Run: 01, Epoch: 299, Loss: 0.7793, Train: 76.34%, Valid: 71.45% Test: 69.79%
# Run: 01, Epoch: 300, Loss: 0.7781, Train: 76.35%, Valid: 71.20% Test: 69.04%
# Run: 01, Epoch: 301, Loss: 0.7772, Train: 76.12%, Valid: 72.47% Test: 71.34%
# Run: 01, Epoch: 302, Loss: 0.7783, Train: 75.87%, Valid: 72.26% Test: 71.11%
# Run: 01, Epoch: 303, Loss: 0.7780, Train: 75.84%, Valid: 72.20% Test: 71.14%
# Run: 01, Epoch: 304, Loss: 0.7786, Train: 76.23%, Valid: 72.95% Test: 71.82%
# Run: 01, Epoch: 305, Loss: 0.7771, Train: 76.69%, Valid: 72.31% Test: 70.81%
# Run: 01, Epoch: 306, Loss: 0.7746, Train: 76.31%, Valid: 72.68% Test: 71.58%
# Run: 01, Epoch: 307, Loss: 0.7780, Train: 76.15%, Valid: 72.70% Test: 71.70%
# Run: 01, Epoch: 308, Loss: 0.7730, Train: 76.38%, Valid: 72.60% Test: 71.55%
# Run: 01, Epoch: 309, Loss: 0.7712, Train: 75.51%, Valid: 70.52% Test: 68.32%
# Run: 01, Epoch: 310, Loss: 0.7725, Train: 75.32%, Valid: 69.93% Test: 67.97%
# Run: 01, Epoch: 311, Loss: 0.7712, Train: 75.65%, Valid: 71.20% Test: 70.01%
# Run: 01, Epoch: 312, Loss: 0.7706, Train: 76.57%, Valid: 73.15% Test: 72.19%
# Run: 01, Epoch: 313, Loss: 0.7697, Train: 75.84%, Valid: 71.10% Test: 68.81%
# Run: 01, Epoch: 314, Loss: 0.7733, Train: 76.22%, Valid: 72.59% Test: 71.61%
# Run: 01, Epoch: 315, Loss: 0.7690, Train: 76.37%, Valid: 72.58% Test: 72.05%
# Run: 01, Epoch: 316, Loss: 0.7701, Train: 76.48%, Valid: 72.50% Test: 70.99%
# Run: 01, Epoch: 317, Loss: 0.7687, Train: 76.62%, Valid: 72.62% Test: 70.74%
# Run: 01, Epoch: 318, Loss: 0.7698, Train: 76.92%, Valid: 73.54% Test: 72.30%
# Run: 01, Epoch: 319, Loss: 0.7675, Train: 77.09%, Valid: 73.37% Test: 72.18%
# Run: 01, Epoch: 320, Loss: 0.7655, Train: 76.40%, Valid: 72.35% Test: 70.88%
# Run: 01, Epoch: 321, Loss: 0.7646, Train: 76.69%, Valid: 72.76% Test: 71.04%
# Run: 01, Epoch: 322, Loss: 0.7662, Train: 76.92%, Valid: 73.15% Test: 71.72%
# Run: 01, Epoch: 323, Loss: 0.7650, Train: 76.92%, Valid: 72.49% Test: 70.85%
# Run: 01, Epoch: 324, Loss: 0.7658, Train: 77.07%, Valid: 72.61% Test: 71.22%
# Run: 01, Epoch: 325, Loss: 0.7610, Train: 76.79%, Valid: 73.18% Test: 72.56%
# Run: 01, Epoch: 326, Loss: 0.7644, Train: 76.27%, Valid: 72.50% Test: 71.93%
# Run: 01, Epoch: 327, Loss: 0.7638, Train: 76.88%, Valid: 72.96% Test: 71.70%
# Run: 01, Epoch: 328, Loss: 0.7619, Train: 76.51%, Valid: 72.18% Test: 70.12%
# Run: 01, Epoch: 329, Loss: 0.7607, Train: 76.81%, Valid: 72.09% Test: 69.82%
# Run: 01, Epoch: 330, Loss: 0.7611, Train: 76.59%, Valid: 71.91% Test: 71.10%
# Run: 01, Epoch: 331, Loss: 0.7629, Train: 76.32%, Valid: 71.50% Test: 69.40%
# Run: 01, Epoch: 332, Loss: 0.7613, Train: 76.89%, Valid: 72.79% Test: 71.60%
# Run: 01, Epoch: 333, Loss: 0.7595, Train: 77.24%, Valid: 73.43% Test: 72.54%
# Run: 01, Epoch: 334, Loss: 0.7603, Train: 76.85%, Valid: 72.06% Test: 69.81%
# Run: 01, Epoch: 335, Loss: 0.7616, Train: 77.08%, Valid: 72.98% Test: 71.84%
# Run: 01, Epoch: 336, Loss: 0.7624, Train: 76.88%, Valid: 73.26% Test: 72.38%
# Run: 01, Epoch: 337, Loss: 0.7595, Train: 76.17%, Valid: 72.25% Test: 71.24%
# Run: 01, Epoch: 338, Loss: 0.7587, Train: 76.58%, Valid: 72.65% Test: 71.68%
# Run: 01, Epoch: 339, Loss: 0.7567, Train: 77.16%, Valid: 72.09% Test: 70.39%
# Run: 01, Epoch: 340, Loss: 0.7563, Train: 77.08%, Valid: 72.21% Test: 70.35%
# Run: 01, Epoch: 341, Loss: 0.7546, Train: 77.12%, Valid: 72.41% Test: 69.77%
# Run: 01, Epoch: 342, Loss: 0.7550, Train: 76.91%, Valid: 72.73% Test: 71.21%
# Run: 01, Epoch: 343, Loss: 0.7566, Train: 76.70%, Valid: 72.53% Test: 71.39%
# Run: 01, Epoch: 344, Loss: 0.7541, Train: 77.11%, Valid: 72.06% Test: 69.96%
# Run: 01, Epoch: 345, Loss: 0.7556, Train: 77.40%, Valid: 72.38% Test: 70.53%
# Run: 01, Epoch: 346, Loss: 0.7546, Train: 77.39%, Valid: 72.99% Test: 71.58%
# Run: 01, Epoch: 347, Loss: 0.7550, Train: 77.30%, Valid: 72.51% Test: 70.77%
# Run: 01, Epoch: 348, Loss: 0.7532, Train: 77.00%, Valid: 72.47% Test: 70.89%
# Run: 01, Epoch: 349, Loss: 0.7557, Train: 76.44%, Valid: 71.57% Test: 70.07%
# Run: 01, Epoch: 350, Loss: 0.7551, Train: 77.50%, Valid: 73.03% Test: 71.52%
# Run: 01, Epoch: 351, Loss: 0.7519, Train: 77.37%, Valid: 73.19% Test: 71.86%
# Run: 01, Epoch: 352, Loss: 0.7532, Train: 77.34%, Valid: 72.83% Test: 70.93%
# Run: 01, Epoch: 353, Loss: 0.7524, Train: 77.04%, Valid: 72.41% Test: 70.86%
# Run: 01, Epoch: 354, Loss: 0.7494, Train: 77.15%, Valid: 72.13% Test: 70.69%
# Run: 01, Epoch: 355, Loss: 0.7473, Train: 77.23%, Valid: 72.54% Test: 71.35%
# Run: 01, Epoch: 356, Loss: 0.7503, Train: 77.35%, Valid: 72.61% Test: 71.10%
# Run: 01, Epoch: 357, Loss: 0.7507, Train: 77.39%, Valid: 72.86% Test: 71.48%
# Run: 01, Epoch: 358, Loss: 0.7480, Train: 77.39%, Valid: 73.00% Test: 72.11%
# Run: 01, Epoch: 359, Loss: 0.7510, Train: 77.23%, Valid: 72.27% Test: 70.25%
# Run: 01, Epoch: 360, Loss: 0.7497, Train: 77.03%, Valid: 72.32% Test: 70.46%
# Run: 01, Epoch: 361, Loss: 0.7489, Train: 77.28%, Valid: 73.36% Test: 72.53%
# Run: 01, Epoch: 362, Loss: 0.7477, Train: 77.28%, Valid: 72.77% Test: 71.02%
# Run: 01, Epoch: 363, Loss: 0.7460, Train: 77.49%, Valid: 71.95% Test: 69.60%
# Run: 01, Epoch: 364, Loss: 0.7476, Train: 77.48%, Valid: 72.89% Test: 71.06%
# Run: 01, Epoch: 365, Loss: 0.7479, Train: 77.63%, Valid: 72.96% Test: 71.55%
# Run: 01, Epoch: 366, Loss: 0.7463, Train: 77.38%, Valid: 72.37% Test: 70.78%
# Run: 01, Epoch: 367, Loss: 0.7460, Train: 77.44%, Valid: 72.82% Test: 71.67%
# Run: 01, Epoch: 368, Loss: 0.7468, Train: 76.92%, Valid: 72.10% Test: 71.34%
# Run: 01, Epoch: 369, Loss: 0.7435, Train: 77.50%, Valid: 72.96% Test: 71.64%
# Run: 01, Epoch: 370, Loss: 0.7431, Train: 77.53%, Valid: 72.30% Test: 70.30%
# Run: 01, Epoch: 371, Loss: 0.7443, Train: 77.15%, Valid: 72.04% Test: 70.21%
# Run: 01, Epoch: 372, Loss: 0.7443, Train: 77.62%, Valid: 72.90% Test: 71.77%
# Run: 01, Epoch: 373, Loss: 0.7453, Train: 77.73%, Valid: 72.62% Test: 70.47%
# Run: 01, Epoch: 374, Loss: 0.7430, Train: 77.78%, Valid: 72.99% Test: 71.41%
# Run: 01, Epoch: 375, Loss: 0.7431, Train: 77.39%, Valid: 72.63% Test: 70.66%
# Run: 01, Epoch: 376, Loss: 0.7440, Train: 77.07%, Valid: 71.63% Test: 69.60%
# Run: 01, Epoch: 377, Loss: 0.7422, Train: 76.99%, Valid: 70.25% Test: 67.17%
# Run: 01, Epoch: 378, Loss: 0.7444, Train: 77.38%, Valid: 72.43% Test: 71.02%
# Run: 01, Epoch: 379, Loss: 0.7440, Train: 77.80%, Valid: 73.52% Test: 72.44%
# Run: 01, Epoch: 380, Loss: 0.7407, Train: 77.82%, Valid: 73.21% Test: 71.73%
# Run: 01, Epoch: 381, Loss: 0.7387, Train: 77.06%, Valid: 72.21% Test: 71.58%
# Run: 01, Epoch: 382, Loss: 0.7438, Train: 76.99%, Valid: 72.00% Test: 70.14%
# Run: 01, Epoch: 383, Loss: 0.7438, Train: 77.56%, Valid: 72.91% Test: 71.59%
# Run: 01, Epoch: 384, Loss: 0.7391, Train: 77.75%, Valid: 72.82% Test: 71.84%
# Run: 01, Epoch: 385, Loss: 0.7375, Train: 77.85%, Valid: 73.49% Test: 72.59%
# Run: 01, Epoch: 386, Loss: 0.7410, Train: 77.52%, Valid: 73.11% Test: 71.96%
# Run: 01, Epoch: 387, Loss: 0.7385, Train: 77.40%, Valid: 72.53% Test: 71.30%
# Run: 01, Epoch: 388, Loss: 0.7395, Train: 77.77%, Valid: 73.67% Test: 73.04%
# Run: 01, Epoch: 389, Loss: 0.7352, Train: 77.85%, Valid: 73.56% Test: 72.92%
# Run: 01, Epoch: 390, Loss: 0.7353, Train: 77.70%, Valid: 73.02% Test: 72.05%
# Run: 01, Epoch: 391, Loss: 0.7371, Train: 77.63%, Valid: 73.15% Test: 72.21%
# Run: 01, Epoch: 392, Loss: 0.7370, Train: 77.92%, Valid: 73.02% Test: 71.17%
# Run: 01, Epoch: 393, Loss: 0.7343, Train: 77.81%, Valid: 72.89% Test: 71.65%
# Run: 01, Epoch: 394, Loss: 0.7377, Train: 78.19%, Valid: 73.26% Test: 71.75%
# Run: 01, Epoch: 395, Loss: 0.7366, Train: 77.90%, Valid: 72.75% Test: 71.46%
# Run: 01, Epoch: 396, Loss: 0.7368, Train: 77.91%, Valid: 72.61% Test: 70.74%
# Run: 01, Epoch: 397, Loss: 0.7348, Train: 78.03%, Valid: 73.10% Test: 71.37%
# Run: 01, Epoch: 398, Loss: 0.7330, Train: 78.14%, Valid: 72.62% Test: 70.77%
# Run: 01, Epoch: 399, Loss: 0.7341, Train: 77.80%, Valid: 73.22% Test: 72.42%
# Run: 01, Epoch: 400, Loss: 0.7321, Train: 77.62%, Valid: 72.79% Test: 72.06%
# Run: 01, Epoch: 401, Loss: 0.7329, Train: 77.47%, Valid: 71.00% Test: 68.31%
# Run: 01, Epoch: 402, Loss: 0.7351, Train: 77.46%, Valid: 72.65% Test: 70.86%
# Run: 01, Epoch: 403, Loss: 0.7342, Train: 77.62%, Valid: 73.58% Test: 72.65%
# Run: 01, Epoch: 404, Loss: 0.7322, Train: 77.22%, Valid: 73.37% Test: 72.62%
# Run: 01, Epoch: 405, Loss: 0.7330, Train: 77.91%, Valid: 73.81% Test: 72.41%
# Run: 01, Epoch: 406, Loss: 0.7339, Train: 77.51%, Valid: 71.39% Test: 68.54%
# Run: 01, Epoch: 407, Loss: 0.7325, Train: 77.12%, Valid: 70.95% Test: 68.18%
# Run: 01, Epoch: 408, Loss: 0.7352, Train: 76.89%, Valid: 72.39% Test: 70.43%
# Run: 01, Epoch: 409, Loss: 0.7326, Train: 77.98%, Valid: 73.24% Test: 71.80%
# Run: 01, Epoch: 410, Loss: 0.7312, Train: 77.85%, Valid: 73.21% Test: 72.14%
# Run: 01, Epoch: 411, Loss: 0.7323, Train: 78.09%, Valid: 73.18% Test: 72.63%
# Run: 01, Epoch: 412, Loss: 0.7307, Train: 77.78%, Valid: 72.59% Test: 70.71%
# Run: 01, Epoch: 413, Loss: 0.7362, Train: 77.47%, Valid: 72.18% Test: 69.85%
# Run: 01, Epoch: 414, Loss: 0.7292, Train: 77.44%, Valid: 72.40% Test: 70.63%
# Run: 01, Epoch: 415, Loss: 0.7310, Train: 77.85%, Valid: 73.40% Test: 72.02%
# Run: 01, Epoch: 416, Loss: 0.7310, Train: 77.81%, Valid: 72.91% Test: 71.89%
# Run: 01, Epoch: 417, Loss: 0.7296, Train: 77.26%, Valid: 72.08% Test: 70.59%
# Run: 01, Epoch: 418, Loss: 0.7291, Train: 77.30%, Valid: 72.59% Test: 70.79%
# Run: 01, Epoch: 419, Loss: 0.7296, Train: 78.16%, Valid: 73.40% Test: 71.97%
# Run: 01, Epoch: 420, Loss: 0.7291, Train: 78.07%, Valid: 73.30% Test: 72.14%
# Run: 01, Epoch: 421, Loss: 0.7270, Train: 77.48%, Valid: 72.85% Test: 72.48%
# Run: 01, Epoch: 422, Loss: 0.7284, Train: 77.64%, Valid: 72.26% Test: 70.23%
# Run: 01, Epoch: 423, Loss: 0.7295, Train: 77.87%, Valid: 71.92% Test: 69.83%
# Run: 01, Epoch: 424, Loss: 0.7259, Train: 77.34%, Valid: 71.31% Test: 69.80%
# Run: 01, Epoch: 425, Loss: 0.7278, Train: 77.83%, Valid: 72.95% Test: 72.26%
# Run: 01, Epoch: 426, Loss: 0.7280, Train: 78.28%, Valid: 73.15% Test: 71.50%
# Run: 01, Epoch: 427, Loss: 0.7251, Train: 77.53%, Valid: 71.81% Test: 69.74%
# Run: 01, Epoch: 428, Loss: 0.7276, Train: 77.92%, Valid: 72.61% Test: 70.61%
# Run: 01, Epoch: 429, Loss: 0.7283, Train: 78.10%, Valid: 73.15% Test: 71.33%
# Run: 01, Epoch: 430, Loss: 0.7271, Train: 77.55%, Valid: 71.85% Test: 70.26%
# Run: 01, Epoch: 431, Loss: 0.7252, Train: 77.75%, Valid: 72.26% Test: 70.52%
# Run: 01, Epoch: 432, Loss: 0.7274, Train: 77.69%, Valid: 73.29% Test: 72.25%
# Run: 01, Epoch: 433, Loss: 0.7236, Train: 77.90%, Valid: 72.27% Test: 70.61%
# Run: 01, Epoch: 434, Loss: 0.7264, Train: 77.54%, Valid: 71.25% Test: 69.39%
# Run: 01, Epoch: 435, Loss: 0.7240, Train: 78.22%, Valid: 73.40% Test: 72.67%
# Run: 01, Epoch: 436, Loss: 0.7239, Train: 77.91%, Valid: 73.36% Test: 72.84%
# Run: 01, Epoch: 437, Loss: 0.7256, Train: 78.01%, Valid: 72.66% Test: 71.21%
# Run: 01, Epoch: 438, Loss: 0.7191, Train: 78.13%, Valid: 72.28% Test: 70.28%
# Run: 01, Epoch: 439, Loss: 0.7205, Train: 78.42%, Valid: 73.44% Test: 72.29%
# Run: 01, Epoch: 440, Loss: 0.7212, Train: 78.41%, Valid: 73.11% Test: 71.49%
# Run: 01, Epoch: 441, Loss: 0.7195, Train: 78.26%, Valid: 72.13% Test: 69.98%
# Run: 01, Epoch: 442, Loss: 0.7225, Train: 78.57%, Valid: 73.07% Test: 71.47%
# Run: 01, Epoch: 443, Loss: 0.7233, Train: 77.99%, Valid: 72.76% Test: 71.29%
# Run: 01, Epoch: 444, Loss: 0.7230, Train: 78.38%, Valid: 73.43% Test: 71.93%
# Run: 01, Epoch: 445, Loss: 0.7159, Train: 77.80%, Valid: 73.12% Test: 72.05%
# Run: 01, Epoch: 446, Loss: 0.7247, Train: 78.37%, Valid: 73.03% Test: 71.39%
# Run: 01, Epoch: 447, Loss: 0.7192, Train: 78.30%, Valid: 72.54% Test: 70.56%
# Run: 01, Epoch: 448, Loss: 0.7181, Train: 78.09%, Valid: 72.97% Test: 71.30%
# Run: 01, Epoch: 449, Loss: 0.7223, Train: 78.31%, Valid: 72.41% Test: 70.40%
# Run: 01, Epoch: 450, Loss: 0.7203, Train: 78.17%, Valid: 72.12% Test: 70.12%
# Run: 01, Epoch: 451, Loss: 0.7185, Train: 77.79%, Valid: 72.13% Test: 70.65%
# Run: 01, Epoch: 452, Loss: 0.7188, Train: 78.03%, Valid: 72.50% Test: 70.38%
# Run: 01, Epoch: 453, Loss: 0.7191, Train: 78.21%, Valid: 71.90% Test: 69.54%
# Run: 01, Epoch: 454, Loss: 0.7179, Train: 77.84%, Valid: 72.53% Test: 71.56%
# Run: 01, Epoch: 455, Loss: 0.7172, Train: 78.07%, Valid: 72.70% Test: 71.69%
# Run: 01, Epoch: 456, Loss: 0.7168, Train: 78.29%, Valid: 73.44% Test: 72.36%
# Run: 01, Epoch: 457, Loss: 0.7190, Train: 78.57%, Valid: 73.36% Test: 72.42%
# Run: 01, Epoch: 458, Loss: 0.7175, Train: 78.24%, Valid: 72.49% Test: 70.57%
# Run: 01, Epoch: 459, Loss: 0.7146, Train: 78.42%, Valid: 72.69% Test: 70.49%
# Run: 01, Epoch: 460, Loss: 0.7146, Train: 77.61%, Valid: 71.71% Test: 70.61%
# Run: 01, Epoch: 461, Loss: 0.7175, Train: 78.24%, Valid: 72.41% Test: 70.18%
# Run: 01, Epoch: 462, Loss: 0.7172, Train: 78.11%, Valid: 73.13% Test: 71.80%
# Run: 01, Epoch: 463, Loss: 0.7146, Train: 78.15%, Valid: 72.81% Test: 71.81%
# Run: 01, Epoch: 464, Loss: 0.7148, Train: 78.37%, Valid: 73.27% Test: 72.06%
# Run: 01, Epoch: 465, Loss: 0.7137, Train: 78.32%, Valid: 72.91% Test: 71.51%
# Run: 01, Epoch: 466, Loss: 0.7138, Train: 78.46%, Valid: 72.76% Test: 71.30%
# Run: 01, Epoch: 467, Loss: 0.7171, Train: 78.34%, Valid: 73.36% Test: 72.21%
# Run: 01, Epoch: 468, Loss: 0.7134, Train: 77.99%, Valid: 72.67% Test: 71.52%
# Run: 01, Epoch: 469, Loss: 0.7157, Train: 78.52%, Valid: 72.98% Test: 71.46%
# Run: 01, Epoch: 470, Loss: 0.7129, Train: 78.41%, Valid: 72.62% Test: 70.60%
# Run: 01, Epoch: 471, Loss: 0.7130, Train: 78.58%, Valid: 72.87% Test: 71.17%
# Run: 01, Epoch: 472, Loss: 0.7105, Train: 78.46%, Valid: 73.68% Test: 72.54%
# Run: 01, Epoch: 473, Loss: 0.7123, Train: 78.26%, Valid: 72.90% Test: 71.02%
# Run: 01, Epoch: 474, Loss: 0.7118, Train: 77.70%, Valid: 71.46% Test: 68.57%
# Run: 01, Epoch: 475, Loss: 0.7128, Train: 78.33%, Valid: 72.26% Test: 70.41%
# Run: 01, Epoch: 476, Loss: 0.7126, Train: 76.75%, Valid: 69.84% Test: 69.25%
# Run: 01, Epoch: 477, Loss: 0.7153, Train: 78.32%, Valid: 73.01% Test: 71.09%
# Run: 01, Epoch: 478, Loss: 0.7123, Train: 78.10%, Valid: 72.10% Test: 69.33%
# Run: 01, Epoch: 479, Loss: 0.7127, Train: 77.78%, Valid: 72.68% Test: 71.13%
# Run: 01, Epoch: 480, Loss: 0.7124, Train: 78.59%, Valid: 73.66% Test: 72.59%
# Run: 01, Epoch: 481, Loss: 0.7111, Train: 78.23%, Valid: 73.02% Test: 72.33%
# Run: 01, Epoch: 482, Loss: 0.7107, Train: 78.24%, Valid: 72.77% Test: 71.82%
# Run: 01, Epoch: 483, Loss: 0.7140, Train: 78.01%, Valid: 72.03% Test: 70.24%
# Run: 01, Epoch: 484, Loss: 0.7108, Train: 77.98%, Valid: 71.88% Test: 69.81%
# Run: 01, Epoch: 485, Loss: 0.7100, Train: 78.03%, Valid: 72.74% Test: 71.65%
# Run: 01, Epoch: 486, Loss: 0.7114, Train: 78.50%, Valid: 72.96% Test: 70.93%
# Run: 01, Epoch: 487, Loss: 0.7091, Train: 77.83%, Valid: 71.65% Test: 68.82%
# Run: 01, Epoch: 488, Loss: 0.7088, Train: 78.53%, Valid: 73.23% Test: 72.05%
# Run: 01, Epoch: 489, Loss: 0.7073, Train: 78.68%, Valid: 72.64% Test: 70.39%
# Run: 01, Epoch: 490, Loss: 0.7069, Train: 78.42%, Valid: 72.09% Test: 69.94%
# Run: 01, Epoch: 491, Loss: 0.7086, Train: 78.74%, Valid: 73.67% Test: 72.35%
# Run: 01, Epoch: 492, Loss: 0.7070, Train: 78.71%, Valid: 73.69% Test: 72.37%
# Run: 01, Epoch: 493, Loss: 0.7083, Train: 77.98%, Valid: 73.22% Test: 72.25%
# Run: 01, Epoch: 494, Loss: 0.7110, Train: 78.81%, Valid: 73.58% Test: 72.45%
# Run: 01, Epoch: 495, Loss: 0.7035, Train: 78.51%, Valid: 73.27% Test: 71.96%
# Run: 01, Epoch: 496, Loss: 0.7093, Train: 78.63%, Valid: 73.30% Test: 72.14%
# Run: 01, Epoch: 497, Loss: 0.7097, Train: 78.68%, Valid: 73.52% Test: 72.53%
# Run: 01, Epoch: 498, Loss: 0.7043, Train: 78.70%, Valid: 73.63% Test: 72.24%
# Run: 01, Epoch: 499, Loss: 0.7052, Train: 78.53%, Valid: 72.24% Test: 69.94%
# Correct and smooth...
# Done!
# Train: 0.9815, Val: 0.7381, Test: 0.7365
# 155824
# Run: 02, Epoch: 00, Loss: 4.0300, Train: 19.53%, Valid: 23.02% Test: 21.64%
# Run: 02, Epoch: 01, Loss: 2.9346, Train: 28.38%, Valid: 29.96% Test: 27.20%
# Run: 02, Epoch: 02, Loss: 2.6270, Train: 14.03%, Valid: 24.55% Test: 22.81%
# Run: 02, Epoch: 03, Loss: 2.6099, Train: 25.96%, Valid: 29.37% Test: 26.23%
# Run: 02, Epoch: 04, Loss: 2.4243, Train: 28.40%, Valid: 30.46% Test: 27.43%
# Run: 02, Epoch: 05, Loss: 2.3249, Train: 19.90%, Valid: 8.92% Test: 6.68%
# Run: 02, Epoch: 06, Loss: 2.1923, Train: 20.90%, Valid: 8.97% Test: 6.97%
# Run: 02, Epoch: 07, Loss: 2.0520, Train: 20.91%, Valid: 9.09% Test: 7.14%
# Run: 02, Epoch: 08, Loss: 1.9522, Train: 21.43%, Valid: 9.63% Test: 7.52%
# Run: 02, Epoch: 09, Loss: 1.8487, Train: 24.68%, Valid: 12.98% Test: 10.68%
# Run: 02, Epoch: 10, Loss: 1.7905, Train: 30.72%, Valid: 20.30% Test: 19.46%
# Run: 02, Epoch: 11, Loss: 1.7477, Train: 32.46%, Valid: 21.52% Test: 19.69%
# Run: 02, Epoch: 12, Loss: 1.7000, Train: 37.85%, Valid: 32.56% Test: 32.11%
# Run: 02, Epoch: 13, Loss: 1.6493, Train: 45.19%, Valid: 47.89% Test: 48.34%
# Run: 02, Epoch: 14, Loss: 1.6111, Train: 47.83%, Valid: 51.44% Test: 52.85%
# Run: 02, Epoch: 15, Loss: 1.5714, Train: 49.47%, Valid: 51.43% Test: 53.38%
# Run: 02, Epoch: 16, Loss: 1.5445, Train: 49.58%, Valid: 49.96% Test: 49.88%
# Run: 02, Epoch: 17, Loss: 1.5228, Train: 49.59%, Valid: 46.32% Test: 43.54%
# Run: 02, Epoch: 18, Loss: 1.5040, Train: 49.77%, Valid: 45.79% Test: 42.30%
# Run: 02, Epoch: 19, Loss: 1.4727, Train: 51.33%, Valid: 47.67% Test: 44.55%
# Run: 02, Epoch: 20, Loss: 1.4548, Train: 55.74%, Valid: 55.05% Test: 53.67%
# Run: 02, Epoch: 21, Loss: 1.4245, Train: 59.43%, Valid: 62.46% Test: 62.99%
# Run: 02, Epoch: 22, Loss: 1.4117, Train: 57.47%, Valid: 58.41% Test: 59.42%
# Run: 02, Epoch: 23, Loss: 1.3920, Train: 55.28%, Valid: 53.67% Test: 54.86%
# Run: 02, Epoch: 24, Loss: 1.3837, Train: 54.97%, Valid: 54.33% Test: 55.88%
# Run: 02, Epoch: 25, Loss: 1.3666, Train: 56.87%, Valid: 59.42% Test: 60.58%
# Run: 02, Epoch: 26, Loss: 1.3586, Train: 59.20%, Valid: 62.64% Test: 63.50%
# Run: 02, Epoch: 27, Loss: 1.3458, Train: 59.65%, Valid: 61.75% Test: 60.59%
# Run: 02, Epoch: 28, Loss: 1.3320, Train: 59.92%, Valid: 61.25% Test: 59.30%
# Run: 02, Epoch: 29, Loss: 1.3221, Train: 61.03%, Valid: 62.64% Test: 60.99%
# Run: 02, Epoch: 30, Loss: 1.3050, Train: 61.85%, Valid: 63.18% Test: 62.00%
# Run: 02, Epoch: 31, Loss: 1.2987, Train: 62.59%, Valid: 63.72% Test: 62.58%
# Run: 02, Epoch: 32, Loss: 1.2888, Train: 63.49%, Valid: 64.83% Test: 63.46%
# Run: 02, Epoch: 33, Loss: 1.2772, Train: 64.06%, Valid: 65.28% Test: 63.75%
# Run: 02, Epoch: 34, Loss: 1.2699, Train: 64.26%, Valid: 65.71% Test: 64.13%
# Run: 02, Epoch: 35, Loss: 1.2578, Train: 64.45%, Valid: 66.03% Test: 65.15%
# Run: 02, Epoch: 36, Loss: 1.2555, Train: 64.56%, Valid: 66.05% Test: 65.70%
# Run: 02, Epoch: 37, Loss: 1.2447, Train: 64.65%, Valid: 66.15% Test: 66.15%
# Run: 02, Epoch: 38, Loss: 1.2356, Train: 64.86%, Valid: 66.39% Test: 66.38%
# Run: 02, Epoch: 39, Loss: 1.2282, Train: 65.07%, Valid: 66.44% Test: 66.41%
# Run: 02, Epoch: 40, Loss: 1.2219, Train: 65.32%, Valid: 66.53% Test: 66.12%
# Run: 02, Epoch: 41, Loss: 1.2144, Train: 65.61%, Valid: 66.69% Test: 65.94%
# Run: 02, Epoch: 42, Loss: 1.2071, Train: 65.95%, Valid: 66.87% Test: 66.12%
# Run: 02, Epoch: 43, Loss: 1.2022, Train: 66.16%, Valid: 66.98% Test: 66.39%
# Run: 02, Epoch: 44, Loss: 1.1961, Train: 66.17%, Valid: 67.12% Test: 66.56%
# Run: 02, Epoch: 45, Loss: 1.1902, Train: 66.08%, Valid: 67.16% Test: 66.56%
# Run: 02, Epoch: 46, Loss: 1.1844, Train: 66.22%, Valid: 67.25% Test: 66.47%
# Run: 02, Epoch: 47, Loss: 1.1795, Train: 66.44%, Valid: 67.30% Test: 66.52%
# Run: 02, Epoch: 48, Loss: 1.1765, Train: 66.45%, Valid: 67.09% Test: 66.27%
# Run: 02, Epoch: 49, Loss: 1.1701, Train: 66.11%, Valid: 66.47% Test: 65.20%
# Run: 02, Epoch: 50, Loss: 1.1669, Train: 66.13%, Valid: 66.49% Test: 65.46%
# Run: 02, Epoch: 51, Loss: 1.1622, Train: 66.49%, Valid: 67.25% Test: 66.92%
# Run: 02, Epoch: 52, Loss: 1.1531, Train: 66.61%, Valid: 67.71% Test: 67.43%
# Run: 02, Epoch: 53, Loss: 1.1526, Train: 66.94%, Valid: 67.95% Test: 67.80%
# Run: 02, Epoch: 54, Loss: 1.1501, Train: 67.02%, Valid: 67.62% Test: 67.18%
# Run: 02, Epoch: 55, Loss: 1.1433, Train: 67.07%, Valid: 67.43% Test: 66.42%
# Run: 02, Epoch: 56, Loss: 1.1335, Train: 67.54%, Valid: 67.87% Test: 67.21%
# Run: 02, Epoch: 57, Loss: 1.1357, Train: 67.80%, Valid: 68.41% Test: 67.86%
# Run: 02, Epoch: 58, Loss: 1.1313, Train: 67.75%, Valid: 68.57% Test: 67.96%
# Run: 02, Epoch: 59, Loss: 1.1223, Train: 67.81%, Valid: 68.48% Test: 68.02%
# Run: 02, Epoch: 60, Loss: 1.1216, Train: 67.77%, Valid: 68.12% Test: 67.42%
# Run: 02, Epoch: 61, Loss: 1.1190, Train: 67.83%, Valid: 68.26% Test: 67.37%
# Run: 02, Epoch: 62, Loss: 1.1147, Train: 68.03%, Valid: 68.52% Test: 67.92%
# Run: 02, Epoch: 63, Loss: 1.1112, Train: 68.28%, Valid: 68.92% Test: 68.45%
# Run: 02, Epoch: 64, Loss: 1.1047, Train: 68.39%, Valid: 69.08% Test: 68.94%
# Run: 02, Epoch: 65, Loss: 1.1054, Train: 68.25%, Valid: 68.85% Test: 68.59%
# Run: 02, Epoch: 66, Loss: 1.1000, Train: 68.44%, Valid: 68.93% Test: 68.40%
# Run: 02, Epoch: 67, Loss: 1.0935, Train: 68.58%, Valid: 68.78% Test: 68.04%
# Run: 02, Epoch: 68, Loss: 1.0927, Train: 68.88%, Valid: 68.90% Test: 68.37%
# Run: 02, Epoch: 69, Loss: 1.0895, Train: 68.75%, Valid: 69.13% Test: 68.88%
# Run: 02, Epoch: 70, Loss: 1.0869, Train: 68.63%, Valid: 69.15% Test: 69.09%
# Run: 02, Epoch: 71, Loss: 1.0839, Train: 69.09%, Valid: 69.21% Test: 68.80%
# Run: 02, Epoch: 72, Loss: 1.0829, Train: 68.90%, Valid: 68.76% Test: 67.65%
# Run: 02, Epoch: 73, Loss: 1.0761, Train: 69.14%, Valid: 69.27% Test: 68.30%
# Run: 02, Epoch: 74, Loss: 1.0717, Train: 69.05%, Valid: 69.50% Test: 69.26%
# Run: 02, Epoch: 75, Loss: 1.0726, Train: 69.14%, Valid: 69.60% Test: 69.58%
# Run: 02, Epoch: 76, Loss: 1.0661, Train: 69.53%, Valid: 69.68% Test: 69.36%
# Run: 02, Epoch: 77, Loss: 1.0661, Train: 69.45%, Valid: 69.40% Test: 68.58%
# Run: 02, Epoch: 78, Loss: 1.0661, Train: 69.41%, Valid: 69.42% Test: 68.37%
# Run: 02, Epoch: 79, Loss: 1.0570, Train: 69.59%, Valid: 69.73% Test: 69.25%
# Run: 02, Epoch: 80, Loss: 1.0574, Train: 69.68%, Valid: 70.01% Test: 69.81%
# Run: 02, Epoch: 81, Loss: 1.0549, Train: 69.45%, Valid: 69.73% Test: 69.48%
# Run: 02, Epoch: 82, Loss: 1.0523, Train: 69.55%, Valid: 69.67% Test: 69.07%
# Run: 02, Epoch: 83, Loss: 1.0491, Train: 69.82%, Valid: 69.89% Test: 69.07%
# Run: 02, Epoch: 84, Loss: 1.0468, Train: 69.79%, Valid: 69.81% Test: 69.03%
# Run: 02, Epoch: 85, Loss: 1.0435, Train: 69.90%, Valid: 70.05% Test: 69.90%
# Run: 02, Epoch: 86, Loss: 1.0430, Train: 69.78%, Valid: 70.23% Test: 70.31%
# Run: 02, Epoch: 87, Loss: 1.0379, Train: 69.78%, Valid: 70.06% Test: 70.07%
# Run: 02, Epoch: 88, Loss: 1.0377, Train: 70.05%, Valid: 70.11% Test: 69.64%
# Run: 02, Epoch: 89, Loss: 1.0336, Train: 69.99%, Valid: 69.57% Test: 68.74%
# Run: 02, Epoch: 90, Loss: 1.0325, Train: 69.98%, Valid: 69.49% Test: 68.40%
# Run: 02, Epoch: 91, Loss: 1.0310, Train: 69.56%, Valid: 68.66% Test: 67.88%
# Run: 02, Epoch: 92, Loss: 1.0260, Train: 70.22%, Valid: 69.63% Test: 68.73%
# Run: 02, Epoch: 93, Loss: 1.0292, Train: 70.64%, Valid: 70.26% Test: 69.23%
# Run: 02, Epoch: 94, Loss: 1.0224, Train: 70.55%, Valid: 70.27% Test: 69.40%
# Run: 02, Epoch: 95, Loss: 1.0210, Train: 70.40%, Valid: 70.59% Test: 69.91%
# Run: 02, Epoch: 96, Loss: 1.0180, Train: 70.65%, Valid: 70.77% Test: 70.64%
# Run: 02, Epoch: 97, Loss: 1.0155, Train: 70.93%, Valid: 70.85% Test: 70.32%
# Run: 02, Epoch: 98, Loss: 1.0187, Train: 70.75%, Valid: 70.48% Test: 69.50%
# Run: 02, Epoch: 99, Loss: 1.0147, Train: 70.59%, Valid: 70.07% Test: 68.58%
# Run: 02, Epoch: 100, Loss: 1.0106, Train: 70.67%, Valid: 70.26% Test: 69.26%
# Run: 02, Epoch: 101, Loss: 1.0080, Train: 70.51%, Valid: 70.47% Test: 69.81%
# Run: 02, Epoch: 102, Loss: 1.0089, Train: 70.39%, Valid: 70.77% Test: 70.25%
# Run: 02, Epoch: 103, Loss: 1.0033, Train: 70.78%, Valid: 70.57% Test: 69.94%
# Run: 02, Epoch: 104, Loss: 1.0028, Train: 70.85%, Valid: 70.38% Test: 69.52%
# Run: 02, Epoch: 105, Loss: 1.0021, Train: 70.82%, Valid: 70.52% Test: 69.58%
# Run: 02, Epoch: 106, Loss: 1.0001, Train: 71.02%, Valid: 70.80% Test: 70.31%
# Run: 02, Epoch: 107, Loss: 1.0010, Train: 70.67%, Valid: 70.43% Test: 69.97%
# Run: 02, Epoch: 108, Loss: 0.9980, Train: 70.48%, Valid: 70.18% Test: 69.65%
# Run: 02, Epoch: 109, Loss: 0.9968, Train: 71.38%, Valid: 70.85% Test: 69.85%
# Run: 02, Epoch: 110, Loss: 0.9937, Train: 70.82%, Valid: 70.40% Test: 69.20%
# Run: 02, Epoch: 111, Loss: 0.9911, Train: 70.79%, Valid: 70.68% Test: 69.50%
# Run: 02, Epoch: 112, Loss: 0.9891, Train: 70.90%, Valid: 70.16% Test: 69.24%
# Run: 02, Epoch: 113, Loss: 0.9853, Train: 71.37%, Valid: 70.62% Test: 69.74%
# Run: 02, Epoch: 114, Loss: 0.9860, Train: 71.32%, Valid: 70.78% Test: 70.08%
# Run: 02, Epoch: 115, Loss: 0.9862, Train: 71.39%, Valid: 70.98% Test: 70.71%
# Run: 02, Epoch: 116, Loss: 0.9815, Train: 71.45%, Valid: 71.17% Test: 70.58%
# Run: 02, Epoch: 117, Loss: 0.9831, Train: 71.55%, Valid: 71.08% Test: 70.26%
# Run: 02, Epoch: 118, Loss: 0.9797, Train: 71.70%, Valid: 71.20% Test: 70.63%
# Run: 02, Epoch: 119, Loss: 0.9759, Train: 71.43%, Valid: 70.83% Test: 70.27%
# Run: 02, Epoch: 120, Loss: 0.9788, Train: 71.43%, Valid: 71.07% Test: 70.40%
# Run: 02, Epoch: 121, Loss: 0.9754, Train: 71.53%, Valid: 71.31% Test: 70.55%
# Run: 02, Epoch: 122, Loss: 0.9735, Train: 71.30%, Valid: 70.57% Test: 69.23%
# Run: 02, Epoch: 123, Loss: 0.9708, Train: 71.62%, Valid: 70.60% Test: 69.00%
# Run: 02, Epoch: 124, Loss: 0.9691, Train: 70.96%, Valid: 70.05% Test: 69.25%
# Run: 02, Epoch: 125, Loss: 0.9720, Train: 71.54%, Valid: 71.14% Test: 70.63%
# Run: 02, Epoch: 126, Loss: 0.9698, Train: 71.37%, Valid: 71.43% Test: 71.08%
# Run: 02, Epoch: 127, Loss: 0.9671, Train: 71.50%, Valid: 71.50% Test: 71.10%
# Run: 02, Epoch: 128, Loss: 0.9662, Train: 71.85%, Valid: 71.03% Test: 70.22%
# Run: 02, Epoch: 129, Loss: 0.9613, Train: 71.27%, Valid: 70.07% Test: 68.36%
# Run: 02, Epoch: 130, Loss: 0.9634, Train: 71.03%, Valid: 69.96% Test: 68.54%
# Run: 02, Epoch: 131, Loss: 0.9608, Train: 71.84%, Valid: 71.33% Test: 70.62%
# Run: 02, Epoch: 132, Loss: 0.9593, Train: 71.30%, Valid: 70.71% Test: 69.44%
# Run: 02, Epoch: 133, Loss: 0.9616, Train: 71.86%, Valid: 70.72% Test: 69.00%
# Run: 02, Epoch: 134, Loss: 0.9571, Train: 71.92%, Valid: 70.81% Test: 69.56%
# Run: 02, Epoch: 135, Loss: 0.9560, Train: 72.04%, Valid: 71.08% Test: 69.82%
# Run: 02, Epoch: 136, Loss: 0.9544, Train: 71.88%, Valid: 70.88% Test: 69.81%
# Run: 02, Epoch: 137, Loss: 0.9518, Train: 71.71%, Valid: 70.82% Test: 69.92%
# Run: 02, Epoch: 138, Loss: 0.9520, Train: 71.93%, Valid: 71.53% Test: 70.77%
# Run: 02, Epoch: 139, Loss: 0.9530, Train: 72.00%, Valid: 71.67% Test: 71.25%
# Run: 02, Epoch: 140, Loss: 0.9479, Train: 71.95%, Valid: 70.94% Test: 70.08%
# Run: 02, Epoch: 141, Loss: 0.9512, Train: 71.45%, Valid: 70.02% Test: 69.06%
# Run: 02, Epoch: 142, Loss: 0.9480, Train: 72.25%, Valid: 70.66% Test: 68.60%
# Run: 02, Epoch: 143, Loss: 0.9444, Train: 71.93%, Valid: 70.86% Test: 69.29%
# Run: 02, Epoch: 144, Loss: 0.9442, Train: 70.65%, Valid: 69.71% Test: 68.76%
# Run: 02, Epoch: 145, Loss: 0.9440, Train: 71.60%, Valid: 71.17% Test: 70.58%
# Run: 02, Epoch: 146, Loss: 0.9428, Train: 71.53%, Valid: 70.27% Test: 69.91%
# Run: 02, Epoch: 147, Loss: 0.9387, Train: 72.04%, Valid: 70.87% Test: 69.51%
# Run: 02, Epoch: 148, Loss: 0.9416, Train: 72.42%, Valid: 70.96% Test: 69.36%
# Run: 02, Epoch: 149, Loss: 0.9363, Train: 72.34%, Valid: 71.49% Test: 70.55%
# Run: 02, Epoch: 150, Loss: 0.9379, Train: 71.95%, Valid: 71.09% Test: 70.23%
# Run: 02, Epoch: 151, Loss: 0.9362, Train: 72.48%, Valid: 71.74% Test: 70.98%
# Run: 02, Epoch: 152, Loss: 0.9345, Train: 71.41%, Valid: 70.39% Test: 69.86%
# Run: 02, Epoch: 153, Loss: 0.9338, Train: 72.33%, Valid: 71.20% Test: 69.91%
# Run: 02, Epoch: 154, Loss: 0.9350, Train: 72.50%, Valid: 71.55% Test: 70.17%
# Run: 02, Epoch: 155, Loss: 0.9319, Train: 72.44%, Valid: 71.61% Test: 70.74%
# Run: 02, Epoch: 156, Loss: 0.9322, Train: 72.14%, Valid: 70.56% Test: 69.42%
# Run: 02, Epoch: 157, Loss: 0.9305, Train: 72.27%, Valid: 70.42% Test: 69.13%
# Run: 02, Epoch: 158, Loss: 0.9298, Train: 72.51%, Valid: 71.51% Test: 70.58%
# Run: 02, Epoch: 159, Loss: 0.9295, Train: 72.08%, Valid: 71.69% Test: 71.07%
# Run: 02, Epoch: 160, Loss: 0.9262, Train: 72.31%, Valid: 71.69% Test: 71.34%
# Run: 02, Epoch: 161, Loss: 0.9261, Train: 72.61%, Valid: 71.63% Test: 71.09%
# Run: 02, Epoch: 162, Loss: 0.9240, Train: 72.11%, Valid: 70.57% Test: 69.79%
# Run: 02, Epoch: 163, Loss: 0.9195, Train: 72.58%, Valid: 70.67% Test: 68.84%
# Run: 02, Epoch: 164, Loss: 0.9240, Train: 72.36%, Valid: 70.62% Test: 68.94%
# Run: 02, Epoch: 165, Loss: 0.9204, Train: 72.61%, Valid: 71.45% Test: 70.47%
# Run: 02, Epoch: 166, Loss: 0.9226, Train: 73.00%, Valid: 71.63% Test: 70.25%
# Run: 02, Epoch: 167, Loss: 0.9210, Train: 72.49%, Valid: 70.32% Test: 68.92%
# ...
# Run: 10, Epoch: 295, Loss: 0.8092, Train: 75.51%, Valid: 71.79% Test: 70.16%
# Run: 10, Epoch: 296, Loss: 0.8134, Train: 75.70%, Valid: 72.77% Test: 71.20%
# Run: 10, Epoch: 297, Loss: 0.8112, Train: 75.68%, Valid: 71.96% Test: 70.15%
# Run: 10, Epoch: 298, Loss: 0.8099, Train: 75.64%, Valid: 72.21% Test: 70.70%
# Run: 10, Epoch: 299, Loss: 0.8100, Train: 75.58%, Valid: 71.94% Test: 69.86%
# Run: 10, Epoch: 300, Loss: 0.8085, Train: 75.53%, Valid: 72.13% Test: 70.58%
# Run: 10, Epoch: 301, Loss: 0.8089, Train: 75.49%, Valid: 72.22% Test: 71.48%
# Run: 10, Epoch: 302, Loss: 0.8095, Train: 75.57%, Valid: 72.47% Test: 71.57%
# Run: 10, Epoch: 303, Loss: 0.8074, Train: 75.46%, Valid: 72.12% Test: 70.65%
# Run: 10, Epoch: 304, Loss: 0.8064, Train: 75.78%, Valid: 72.45% Test: 71.01%
# Run: 10, Epoch: 305, Loss: 0.8058, Train: 76.09%, Valid: 72.84% Test: 71.60%
# Run: 10, Epoch: 306, Loss: 0.8050, Train: 76.00%, Valid: 72.65% Test: 70.99%
# Run: 10, Epoch: 307, Loss: 0.8048, Train: 75.90%, Valid: 72.21% Test: 70.07%
# Run: 10, Epoch: 308, Loss: 0.8050, Train: 75.53%, Valid: 72.51% Test: 71.06%
# Run: 10, Epoch: 309, Loss: 0.8037, Train: 75.89%, Valid: 72.82% Test: 71.67%
# Run: 10, Epoch: 310, Loss: 0.8033, Train: 76.00%, Valid: 72.69% Test: 71.43%
# Run: 10, Epoch: 311, Loss: 0.8035, Train: 75.67%, Valid: 71.44% Test: 69.79%
# Run: 10, Epoch: 312, Loss: 0.8012, Train: 75.81%, Valid: 72.12% Test: 70.58%
# Run: 10, Epoch: 313, Loss: 0.7992, Train: 76.11%, Valid: 72.58% Test: 70.84%
# Run: 10, Epoch: 314, Loss: 0.8026, Train: 76.16%, Valid: 72.90% Test: 71.45%
# Run: 10, Epoch: 315, Loss: 0.8005, Train: 76.19%, Valid: 72.74% Test: 71.99%
# Run: 10, Epoch: 316, Loss: 0.7971, Train: 76.02%, Valid: 72.57% Test: 71.97%
# Run: 10, Epoch: 317, Loss: 0.7995, Train: 76.32%, Valid: 72.75% Test: 71.33%
# Run: 10, Epoch: 318, Loss: 0.7983, Train: 76.01%, Valid: 72.16% Test: 70.88%
# Run: 10, Epoch: 319, Loss: 0.7964, Train: 75.93%, Valid: 72.33% Test: 70.91%
# Run: 10, Epoch: 320, Loss: 0.7990, Train: 75.98%, Valid: 71.89% Test: 70.02%
# Run: 10, Epoch: 321, Loss: 0.7976, Train: 76.07%, Valid: 72.04% Test: 70.18%
# Run: 10, Epoch: 322, Loss: 0.7974, Train: 76.17%, Valid: 72.51% Test: 71.14%
# Run: 10, Epoch: 323, Loss: 0.7979, Train: 76.45%, Valid: 72.93% Test: 71.75%
# Run: 10, Epoch: 324, Loss: 0.7948, Train: 76.17%, Valid: 72.68% Test: 71.40%
# Run: 10, Epoch: 325, Loss: 0.7952, Train: 76.19%, Valid: 72.72% Test: 71.51%
# Run: 10, Epoch: 326, Loss: 0.7939, Train: 76.00%, Valid: 72.59% Test: 71.07%
# Run: 10, Epoch: 327, Loss: 0.7920, Train: 76.27%, Valid: 72.72% Test: 70.97%
# Run: 10, Epoch: 328, Loss: 0.7934, Train: 76.19%, Valid: 72.88% Test: 71.67%
# Run: 10, Epoch: 329, Loss: 0.7969, Train: 75.75%, Valid: 72.17% Test: 71.35%
# Run: 10, Epoch: 330, Loss: 0.7921, Train: 76.17%, Valid: 72.29% Test: 71.14%
# Run: 10, Epoch: 331, Loss: 0.7923, Train: 76.17%, Valid: 71.99% Test: 69.79%
# Run: 10, Epoch: 332, Loss: 0.7953, Train: 76.41%, Valid: 72.99% Test: 71.58%
# Run: 10, Epoch: 333, Loss: 0.7920, Train: 76.44%, Valid: 72.78% Test: 72.00%
# Run: 10, Epoch: 334, Loss: 0.7896, Train: 76.10%, Valid: 72.38% Test: 70.65%
# Run: 10, Epoch: 335, Loss: 0.7909, Train: 75.96%, Valid: 71.48% Test: 69.04%
# Run: 10, Epoch: 336, Loss: 0.7918, Train: 75.94%, Valid: 72.35% Test: 70.51%
# Run: 10, Epoch: 337, Loss: 0.7882, Train: 75.98%, Valid: 72.43% Test: 71.42%
# Run: 10, Epoch: 338, Loss: 0.7855, Train: 76.06%, Valid: 72.63% Test: 71.56%
# Run: 10, Epoch: 339, Loss: 0.7867, Train: 76.32%, Valid: 72.54% Test: 71.12%
# Run: 10, Epoch: 340, Loss: 0.7882, Train: 76.05%, Valid: 72.61% Test: 71.39%
# Run: 10, Epoch: 341, Loss: 0.7891, Train: 76.16%, Valid: 73.18% Test: 72.45%
# Run: 10, Epoch: 342, Loss: 0.7859, Train: 75.98%, Valid: 72.93% Test: 72.24%
# Run: 10, Epoch: 343, Loss: 0.7879, Train: 76.31%, Valid: 72.69% Test: 71.17%
# Run: 10, Epoch: 344, Loss: 0.7858, Train: 76.50%, Valid: 72.29% Test: 70.32%
# Run: 10, Epoch: 345, Loss: 0.7844, Train: 76.11%, Valid: 72.49% Test: 71.16%
# Run: 10, Epoch: 346, Loss: 0.7846, Train: 76.27%, Valid: 72.31% Test: 70.97%
# Run: 10, Epoch: 347, Loss: 0.7840, Train: 76.50%, Valid: 72.56% Test: 70.72%
# Run: 10, Epoch: 348, Loss: 0.7800, Train: 76.27%, Valid: 72.54% Test: 71.01%
# Run: 10, Epoch: 349, Loss: 0.7817, Train: 76.64%, Valid: 72.98% Test: 71.40%
# Run: 10, Epoch: 350, Loss: 0.7825, Train: 75.98%, Valid: 72.17% Test: 70.24%
# Run: 10, Epoch: 351, Loss: 0.7848, Train: 76.43%, Valid: 72.34% Test: 70.45%
# Run: 10, Epoch: 352, Loss: 0.7832, Train: 76.30%, Valid: 72.87% Test: 71.68%
# Run: 10, Epoch: 353, Loss: 0.7812, Train: 76.57%, Valid: 73.04% Test: 71.82%
# Run: 10, Epoch: 354, Loss: 0.7808, Train: 76.78%, Valid: 72.59% Test: 71.02%
# Run: 10, Epoch: 355, Loss: 0.7815, Train: 76.59%, Valid: 72.48% Test: 71.06%
# Run: 10, Epoch: 356, Loss: 0.7781, Train: 76.70%, Valid: 72.74% Test: 71.28%
# Run: 10, Epoch: 357, Loss: 0.7786, Train: 76.72%, Valid: 72.78% Test: 70.96%
# Run: 10, Epoch: 358, Loss: 0.7796, Train: 76.59%, Valid: 72.63% Test: 71.14%
# Run: 10, Epoch: 359, Loss: 0.7769, Train: 76.54%, Valid: 72.74% Test: 71.52%
# Run: 10, Epoch: 360, Loss: 0.7778, Train: 76.53%, Valid: 72.40% Test: 71.10%
# Run: 10, Epoch: 361, Loss: 0.7763, Train: 76.35%, Valid: 72.20% Test: 70.40%
# Run: 10, Epoch: 362, Loss: 0.7766, Train: 76.40%, Valid: 72.14% Test: 70.57%
# Run: 10, Epoch: 363, Loss: 0.7734, Train: 76.35%, Valid: 72.26% Test: 70.64%
# Run: 10, Epoch: 364, Loss: 0.7751, Train: 76.65%, Valid: 73.09% Test: 71.77%
# Run: 10, Epoch: 365, Loss: 0.7757, Train: 76.22%, Valid: 72.55% Test: 71.17%
# Run: 10, Epoch: 366, Loss: 0.7780, Train: 76.87%, Valid: 73.28% Test: 72.15%
# Run: 10, Epoch: 367, Loss: 0.7712, Train: 76.40%, Valid: 72.96% Test: 72.10%
# Run: 10, Epoch: 368, Loss: 0.7757, Train: 76.83%, Valid: 73.43% Test: 72.18%
# Run: 10, Epoch: 369, Loss: 0.7757, Train: 76.61%, Valid: 72.93% Test: 72.19%
# Run: 10, Epoch: 370, Loss: 0.7738, Train: 76.32%, Valid: 72.36% Test: 70.74%
# Run: 10, Epoch: 371, Loss: 0.7681, Train: 76.49%, Valid: 72.75% Test: 71.39%
# Run: 10, Epoch: 372, Loss: 0.7695, Train: 76.67%, Valid: 73.02% Test: 71.93%
# Run: 10, Epoch: 373, Loss: 0.7725, Train: 76.76%, Valid: 73.02% Test: 71.75%
# Run: 10, Epoch: 374, Loss: 0.7679, Train: 76.81%, Valid: 72.40% Test: 70.66%
# Run: 10, Epoch: 375, Loss: 0.7698, Train: 76.91%, Valid: 72.78% Test: 71.90%
# Run: 10, Epoch: 376, Loss: 0.7717, Train: 76.87%, Valid: 72.61% Test: 71.52%
# Run: 10, Epoch: 377, Loss: 0.7702, Train: 76.84%, Valid: 72.87% Test: 71.60%
# Run: 10, Epoch: 378, Loss: 0.7701, Train: 76.69%, Valid: 72.95% Test: 71.94%
# Run: 10, Epoch: 379, Loss: 0.7717, Train: 76.82%, Valid: 73.13% Test: 72.39%
# Run: 10, Epoch: 380, Loss: 0.7696, Train: 76.74%, Valid: 72.53% Test: 71.49%
# Run: 10, Epoch: 381, Loss: 0.7736, Train: 76.77%, Valid: 72.27% Test: 70.49%
# Run: 10, Epoch: 382, Loss: 0.7680, Train: 76.98%, Valid: 72.25% Test: 70.78%
# Run: 10, Epoch: 383, Loss: 0.7665, Train: 76.76%, Valid: 73.10% Test: 71.92%
# Run: 10, Epoch: 384, Loss: 0.7664, Train: 76.99%, Valid: 73.31% Test: 71.94%
# Run: 10, Epoch: 385, Loss: 0.7649, Train: 76.78%, Valid: 73.07% Test: 72.29%
# Run: 10, Epoch: 386, Loss: 0.7671, Train: 77.17%, Valid: 72.96% Test: 71.94%
# Run: 10, Epoch: 387, Loss: 0.7637, Train: 77.09%, Valid: 72.68% Test: 71.32%
# Run: 10, Epoch: 388, Loss: 0.7659, Train: 76.96%, Valid: 72.96% Test: 71.54%
# Run: 10, Epoch: 389, Loss: 0.7638, Train: 76.82%, Valid: 73.01% Test: 71.45%
# Run: 10, Epoch: 390, Loss: 0.7634, Train: 77.19%, Valid: 72.82% Test: 71.09%
# Run: 10, Epoch: 391, Loss: 0.7644, Train: 77.11%, Valid: 72.48% Test: 70.78%
# Run: 10, Epoch: 392, Loss: 0.7659, Train: 76.67%, Valid: 71.82% Test: 70.64%
# Run: 10, Epoch: 393, Loss: 0.7668, Train: 77.26%, Valid: 73.30% Test: 72.27%
# Run: 10, Epoch: 394, Loss: 0.7647, Train: 77.22%, Valid: 72.87% Test: 71.36%
# Run: 10, Epoch: 395, Loss: 0.7630, Train: 77.26%, Valid: 73.09% Test: 71.45%
# Run: 10, Epoch: 396, Loss: 0.7608, Train: 77.05%, Valid: 73.19% Test: 71.58%
# Run: 10, Epoch: 397, Loss: 0.7643, Train: 77.01%, Valid: 72.83% Test: 71.08%
# Run: 10, Epoch: 398, Loss: 0.7633, Train: 76.91%, Valid: 72.51% Test: 71.62%
# Run: 10, Epoch: 399, Loss: 0.7617, Train: 76.99%, Valid: 72.72% Test: 71.79%
# Run: 10, Epoch: 400, Loss: 0.7618, Train: 76.93%, Valid: 72.54% Test: 70.45%
# Run: 10, Epoch: 401, Loss: 0.7591, Train: 76.85%, Valid: 71.91% Test: 69.57%
# Run: 10, Epoch: 402, Loss: 0.7609, Train: 76.67%, Valid: 72.27% Test: 70.31%
# Run: 10, Epoch: 403, Loss: 0.7612, Train: 77.17%, Valid: 73.21% Test: 71.76%
# Run: 10, Epoch: 404, Loss: 0.7584, Train: 76.97%, Valid: 72.75% Test: 71.41%
# Run: 10, Epoch: 405, Loss: 0.7572, Train: 76.97%, Valid: 72.69% Test: 70.95%
# Run: 10, Epoch: 406, Loss: 0.7568, Train: 77.14%, Valid: 72.84% Test: 71.12%
# Run: 10, Epoch: 407, Loss: 0.7598, Train: 77.23%, Valid: 72.70% Test: 71.28%
# Run: 10, Epoch: 408, Loss: 0.7576, Train: 77.24%, Valid: 72.66% Test: 71.15%
# Run: 10, Epoch: 409, Loss: 0.7545, Train: 76.93%, Valid: 71.58% Test: 69.27%
# Run: 10, Epoch: 410, Loss: 0.7551, Train: 76.98%, Valid: 72.59% Test: 70.75%
# Run: 10, Epoch: 411, Loss: 0.7536, Train: 77.29%, Valid: 73.62% Test: 72.70%
# Run: 10, Epoch: 412, Loss: 0.7559, Train: 77.28%, Valid: 73.29% Test: 72.32%
# Run: 10, Epoch: 413, Loss: 0.7532, Train: 77.21%, Valid: 72.59% Test: 70.95%
# Run: 10, Epoch: 414, Loss: 0.7514, Train: 77.32%, Valid: 72.58% Test: 70.65%
# Run: 10, Epoch: 415, Loss: 0.7546, Train: 77.35%, Valid: 73.19% Test: 71.52%
# Run: 10, Epoch: 416, Loss: 0.7561, Train: 77.41%, Valid: 73.15% Test: 71.79%
# Run: 10, Epoch: 417, Loss: 0.7525, Train: 77.56%, Valid: 73.32% Test: 72.15%
# Run: 10, Epoch: 418, Loss: 0.7521, Train: 77.26%, Valid: 73.09% Test: 72.27%
# Run: 10, Epoch: 419, Loss: 0.7552, Train: 77.38%, Valid: 73.09% Test: 71.84%
# Run: 10, Epoch: 420, Loss: 0.7530, Train: 77.43%, Valid: 73.08% Test: 71.80%
# Run: 10, Epoch: 421, Loss: 0.7515, Train: 77.49%, Valid: 72.94% Test: 71.58%
# Run: 10, Epoch: 422, Loss: 0.7510, Train: 77.25%, Valid: 72.81% Test: 71.77%
# Run: 10, Epoch: 423, Loss: 0.7550, Train: 77.12%, Valid: 72.59% Test: 71.29%
# Run: 10, Epoch: 424, Loss: 0.7478, Train: 77.26%, Valid: 72.44% Test: 70.87%
# Run: 10, Epoch: 425, Loss: 0.7500, Train: 77.60%, Valid: 72.98% Test: 71.23%
# Run: 10, Epoch: 426, Loss: 0.7490, Train: 77.61%, Valid: 73.11% Test: 71.56%
# Run: 10, Epoch: 427, Loss: 0.7506, Train: 77.22%, Valid: 72.46% Test: 71.22%
# Run: 10, Epoch: 428, Loss: 0.7498, Train: 77.50%, Valid: 73.10% Test: 71.81%
# Run: 10, Epoch: 429, Loss: 0.7499, Train: 77.48%, Valid: 73.22% Test: 72.30%
# Run: 10, Epoch: 430, Loss: 0.7445, Train: 77.45%, Valid: 73.05% Test: 71.87%
# Run: 10, Epoch: 431, Loss: 0.7499, Train: 77.52%, Valid: 73.00% Test: 71.55%
# Run: 10, Epoch: 432, Loss: 0.7443, Train: 77.60%, Valid: 72.87% Test: 71.21%
# Run: 10, Epoch: 433, Loss: 0.7495, Train: 77.79%, Valid: 73.05% Test: 71.38%
# Run: 10, Epoch: 434, Loss: 0.7471, Train: 77.61%, Valid: 72.92% Test: 71.68%
# Run: 10, Epoch: 435, Loss: 0.7464, Train: 76.86%, Valid: 72.19% Test: 70.74%
# Run: 10, Epoch: 436, Loss: 0.7471, Train: 77.71%, Valid: 73.02% Test: 71.44%
# Run: 10, Epoch: 437, Loss: 0.7452, Train: 77.69%, Valid: 73.26% Test: 72.46%
# Run: 10, Epoch: 438, Loss: 0.7464, Train: 77.22%, Valid: 72.29% Test: 71.43%
# Run: 10, Epoch: 439, Loss: 0.7464, Train: 77.63%, Valid: 72.44% Test: 71.12%
# Run: 10, Epoch: 440, Loss: 0.7454, Train: 77.82%, Valid: 73.06% Test: 71.74%
# Run: 10, Epoch: 441, Loss: 0.7438, Train: 77.48%, Valid: 73.22% Test: 71.92%
# Run: 10, Epoch: 442, Loss: 0.7427, Train: 77.72%, Valid: 73.30% Test: 72.04%
# Run: 10, Epoch: 443, Loss: 0.7418, Train: 77.85%, Valid: 73.11% Test: 72.11%
# Run: 10, Epoch: 444, Loss: 0.7439, Train: 77.65%, Valid: 72.74% Test: 71.63%
# Run: 10, Epoch: 445, Loss: 0.7442, Train: 77.75%, Valid: 72.75% Test: 71.16%
# Run: 10, Epoch: 446, Loss: 0.7414, Train: 77.24%, Valid: 72.72% Test: 71.74%
# Run: 10, Epoch: 447, Loss: 0.7430, Train: 77.53%, Valid: 73.07% Test: 72.09%
# Run: 10, Epoch: 448, Loss: 0.7430, Train: 77.78%, Valid: 72.83% Test: 71.29%
# Run: 10, Epoch: 449, Loss: 0.7454, Train: 77.56%, Valid: 72.31% Test: 70.98%
# Run: 10, Epoch: 450, Loss: 0.7412, Train: 77.57%, Valid: 73.22% Test: 71.98%
# Run: 10, Epoch: 451, Loss: 0.7391, Train: 77.58%, Valid: 72.70% Test: 70.97%
# Run: 10, Epoch: 452, Loss: 0.7416, Train: 77.80%, Valid: 73.02% Test: 71.48%
# Run: 10, Epoch: 453, Loss: 0.7411, Train: 77.70%, Valid: 72.69% Test: 71.30%
# Run: 10, Epoch: 454, Loss: 0.7391, Train: 77.88%, Valid: 73.16% Test: 71.63%
# Run: 10, Epoch: 455, Loss: 0.7376, Train: 77.87%, Valid: 73.30% Test: 71.77%
# Run: 10, Epoch: 456, Loss: 0.7426, Train: 77.57%, Valid: 73.10% Test: 71.43%
# Run: 10, Epoch: 457, Loss: 0.7394, Train: 77.72%, Valid: 73.02% Test: 71.01%
# Run: 10, Epoch: 458, Loss: 0.7380, Train: 77.92%, Valid: 72.89% Test: 70.94%
# Run: 10, Epoch: 459, Loss: 0.7379, Train: 78.10%, Valid: 73.61% Test: 72.26%
# Run: 10, Epoch: 460, Loss: 0.7367, Train: 77.47%, Valid: 72.80% Test: 71.97%
# Run: 10, Epoch: 461, Loss: 0.7393, Train: 77.69%, Valid: 73.00% Test: 71.42%
# Run: 10, Epoch: 462, Loss: 0.7375, Train: 78.06%, Valid: 73.27% Test: 71.89%
# Run: 10, Epoch: 463, Loss: 0.7369, Train: 77.57%, Valid: 72.88% Test: 72.18%
# Run: 10, Epoch: 464, Loss: 0.7355, Train: 77.82%, Valid: 73.53% Test: 72.63%
# Run: 10, Epoch: 465, Loss: 0.7365, Train: 78.07%, Valid: 73.26% Test: 72.03%
# Run: 10, Epoch: 466, Loss: 0.7349, Train: 78.07%, Valid: 72.79% Test: 71.27%
# Run: 10, Epoch: 467, Loss: 0.7337, Train: 78.13%, Valid: 73.07% Test: 71.59%
# Run: 10, Epoch: 468, Loss: 0.7347, Train: 78.05%, Valid: 73.56% Test: 71.97%
# Run: 10, Epoch: 469, Loss: 0.7314, Train: 77.90%, Valid: 73.07% Test: 71.20%
# Run: 10, Epoch: 470, Loss: 0.7347, Train: 77.98%, Valid: 73.07% Test: 71.63%
# Run: 10, Epoch: 471, Loss: 0.7336, Train: 77.90%, Valid: 72.71% Test: 70.93%
# Run: 10, Epoch: 472, Loss: 0.7319, Train: 78.07%, Valid: 73.11% Test: 71.52%
# Run: 10, Epoch: 473, Loss: 0.7341, Train: 77.93%, Valid: 73.46% Test: 72.55%
# Run: 10, Epoch: 474, Loss: 0.7329, Train: 77.99%, Valid: 73.30% Test: 72.34%
# Run: 10, Epoch: 475, Loss: 0.7336, Train: 78.26%, Valid: 73.14% Test: 71.82%
# Run: 10, Epoch: 476, Loss: 0.7332, Train: 78.14%, Valid: 73.40% Test: 72.32%
# Run: 10, Epoch: 477, Loss: 0.7328, Train: 77.67%, Valid: 72.79% Test: 71.44%
# Run: 10, Epoch: 478, Loss: 0.7299, Train: 78.11%, Valid: 72.77% Test: 70.69%
# Run: 10, Epoch: 479, Loss: 0.7291, Train: 78.06%, Valid: 72.50% Test: 70.78%
# Run: 10, Epoch: 480, Loss: 0.7294, Train: 78.08%, Valid: 73.13% Test: 71.61%
# Run: 10, Epoch: 481, Loss: 0.7288, Train: 78.02%, Valid: 73.45% Test: 71.91%
# Run: 10, Epoch: 482, Loss: 0.7309, Train: 77.61%, Valid: 72.69% Test: 71.18%
# Run: 10, Epoch: 483, Loss: 0.7293, Train: 77.89%, Valid: 73.02% Test: 71.73%
# Run: 10, Epoch: 484, Loss: 0.7281, Train: 78.27%, Valid: 73.36% Test: 72.29%
# Run: 10, Epoch: 485, Loss: 0.7290, Train: 78.26%, Valid: 73.14% Test: 71.28%
# Run: 10, Epoch: 486, Loss: 0.7273, Train: 78.22%, Valid: 72.82% Test: 70.73%
# Run: 10, Epoch: 487, Loss: 0.7278, Train: 78.02%, Valid: 73.38% Test: 72.31%
# Run: 10, Epoch: 488, Loss: 0.7271, Train: 77.66%, Valid: 72.88% Test: 72.13%
# Run: 10, Epoch: 489, Loss: 0.7283, Train: 78.13%, Valid: 73.01% Test: 71.27%
# Run: 10, Epoch: 490, Loss: 0.7283, Train: 77.74%, Valid: 72.23% Test: 69.94%
# Run: 10, Epoch: 491, Loss: 0.7286, Train: 77.88%, Valid: 73.52% Test: 72.34%
# Run: 10, Epoch: 492, Loss: 0.7291, Train: 77.79%, Valid: 72.86% Test: 72.11%
# Run: 10, Epoch: 493, Loss: 0.7304, Train: 77.70%, Valid: 72.66% Test: 71.30%
# Run: 10, Epoch: 494, Loss: 0.7306, Train: 77.95%, Valid: 72.33% Test: 70.77%
# Run: 10, Epoch: 495, Loss: 0.7250, Train: 77.98%, Valid: 72.93% Test: 72.02%
# Run: 10, Epoch: 496, Loss: 0.7277, Train: 78.00%, Valid: 73.39% Test: 72.38%
# Run: 10, Epoch: 497, Loss: 0.7261, Train: 78.13%, Valid: 72.63% Test: 70.79%
# Run: 10, Epoch: 498, Loss: 0.7255, Train: 78.41%, Valid: 72.74% Test: 71.00%
# Run: 10, Epoch: 499, Loss: 0.7233, Train: 78.29%, Valid: 72.88% Test: 71.24%
# Correct and smooth...
# Done!
# Train: 0.9813, Val: 0.7362, Test: 0.7392
# All runs:
# Highest Train: 98.14 ± 0.01
# Highest Valid: 73.63 ± 0.19
#   Final Train: 98.14 ± 0.01
#    Final Test: 73.89 ± 0.17

# %% [markdown]
# # GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! nvidia-smi
# Out:
# Tue Apr 12 06:45:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
